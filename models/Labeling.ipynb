# %% [markdown]
# # FOR A SINGLE FILE

# %%
from IPython.display import display
import ipywidgets as widgets

upload = widgets.FileUpload(accept='.wav', multiple=False)
display(upload)
# Out:
# FileUpload(value=(), accept='.wav', description='Upload')

# %%
if not upload.value:
    print("Please upload an audio file first.")
else:
    uploaded_file = upload.value[0]
    
    uploaded_filename = uploaded_file.name
    content = uploaded_file.content  # bytes
    
    import os
    save_dir = 'uploaded_audio'
    os.makedirs(save_dir, exist_ok=True)
    
    save_path = os.path.join(save_dir, uploaded_filename)
    with open(save_path, 'wb') as f:
        f.write(content)
    
    print(f"✅ Saved uploaded audio file to: {save_path}")
# Out:
# ✅ Saved uploaded audio file to: uploaded_audio\english1.wav

# %%
import IPython.display as ipd

ipd.Audio(save_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import numpy as np

y, sr = librosa.load(save_path, sr=16000)  # load at 16 kHz
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

print("MFCC shape:", mfccs.shape)
# Out:
# MFCC shape: (13, 684)

# %%
import csv

metadata_file = 'metadata.csv'

with open(metadata_file, mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['filename', 'speaker_id', 'transcript']) 
    
    speaker_id = 'user001'
    transcript = 'N/A'  
    
    writer.writerow([save_path, speaker_id, transcript])

print(f"✅ Metadata CSV created: {metadata_file}")
# Out:
# ✅ Metadata CSV created: metadata.csv

# %%
'''from IPython.display import display
import ipywidgets as widgets

upload = widgets.FileUpload(accept='.zip', multiple=False)
display(upload)'''
# Out:
# FileUpload(value=(), accept='.zip', description='Upload')

# %%
'''if not upload.value:
    print("Please upload a ZIP file first.")
else:
    uploaded_file = upload.value[0]  
    
    uploaded_filename = uploaded_file.name
    content = uploaded_file.content  
    
    import zipfile
    import io
    import os
    
    zip_file = zipfile.ZipFile(io.BytesIO(content))
    
    extract_dir = 'voice_data'
    os.makedirs(extract_dir, exist_ok=True)
    
    zip_file.extractall(extract_dir)
    print(f"✅ Extracted to folder: {extract_dir}")'''

# %%
'''print("Contents of extracted folder:")
print(os.listdir(extract_dir))'''

# %%
'''import csv

metadata_file = os.path.join(extract_dir, 'metadata.csv')

with open(metadata_file, mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['filename', 'speaker_id', 'transcript'])

    for speaker_folder in os.listdir(extract_dir):
        speaker_path = os.path.join(extract_dir, speaker_folder)
        if os.path.isdir(speaker_path):
            for file_name in os.listdir(speaker_path):
                if file_name.endswith('.wav'):
                    rel_path = os.path.join(speaker_folder, file_name)
                    writer.writerow([rel_path, speaker_folder, "N/A"])

print(f"✅ Metadata CSV created at: {metadata_file}")'''

# %%
'''import os

print("Contents of 'recordings':")
print(os.listdir('recordings'))'''
# Out:
# Contents of 'recordings':
arabic31.mp3', 'arabic31.wav', 'arabic32.mp3', 'arabic32.wav', 'arabic33.mp3', 'arabic33.wav', 'arabic34.mp3', 'arabic34.wav', 'arabic35.mp3', 'arabic35.wav', 'arabic36.mp3', 'arabic36.wav', 'arabic37.mp3', 'arabic37.wav', 'arabic38.mp3', 'arabic38.wav', 'arabic39.mp3', 'arabic39.wav', 'arabic4.mp3', 'arabic4.wav', 'arabic40.mp3', 'arabic40.wav', 'arabic41.mp3', 'arabic41.wav', 'arabic42.mp3', 'arabic42.wav', 'arabic43.mp3', 'arabic43.wav', 'arabic44.mp3', 'arabic44.wav', 'arabic45.mp3', 'arabic45.wav', 'arabic46.mp3', 'arabic46.wav', 'arabic47.mp3', 'arabic47.wav', 'arabic48.mp3', 'arabic48.wav', 'arabic49.mp3', 'arabic49.wav', 'arabic5.mp3', 'arabic5.wav', 'arabic50.mp3', 'arabic50.wav', 'arabic51.mp3', 'arabic51.wav', 'arabic52.mp3', 'arabic52.wav', 'arabic53.mp3', 'arabic53.wav', 'arabic54.mp3', 'arabic54.wav', 'arabic55.mp3', 'arabic55.wav', 'arabic56.mp3', 'arabic56.wav', 'arabic57.mp3', 'arabic57.wav', 'arabic58.mp3', 'arabic58.wav', 'arabic59.mp3', 'arabic59.wav', 'arabic6.mp3', 'arabic6.wav', 'arabic60.mp3', 'arabic60.wav', 'arabic61.mp3', 'arabic61.wav', 'arabic62.mp3', 'arabic62.wav', 'arabic63.mp3', 'arabic63.wav', 'arabic64.mp3', 'arabic64.wav', 'arabic65.mp3', 'arabic65.wav', 'arabic66.mp3', 'arabic66.wav', 'arabic67.mp3', 'arabic67.wav', 'arabic68.mp3', 'arabic68.wav', 'arabic69.mp3', 'arabic69.wav', 'arabic7.mp3', 'arabic7.wav', 'arabic70.mp3', 'arabic70.wav', 'arabic71.mp3', 'arabic71.wav', 'arabic72.mp3', 'arabic72.wav', 'arabic73.mp3', 'arabic73.wav', 'arabic74.mp3', 'arabic74.wav', 'arabic75.mp3', 'arabic75.wav', 'arabic76.mp3', 'arabic76.wav', 'arabic77.mp3', 'arabic77.wav', 'arabic78.mp3', 'arabic78.wav', 'arabic79.mp3', 'arabic79.wav', 'arabic8.mp3', 'arabic8.wav', 'arabic80.mp3', 'arabic80.wav', 'arabic81.mp3', 'arabic81.wav', 'arabic82.mp3', 'arabic82.wav', 'arabic83.mp3', 'arabic83.wav', 'arabic84.mp3', 'arabic84 ...

# %%
'''import os

audio_files = []
for root, _, files in os.walk('recordings'):
    for file in files:
        if file.endswith('.wav'):
            rel_path = os.path.relpath(os.path.join(root, file), 'recordings')
            audio_files.append(rel_path)

print(f"🎧 Found {len(audio_files)} audio files.")'''
# Out:
# 🎧 Found 2138 audio files.

# %%
'''import ipywidgets as widgets
from IPython.display import display, Audio
import os

labels = []  # Store rows of metadata

def label_next(index=0):
    if index >= len(audio_files):
        print("✅ All files labeled.")
        return
    
    file_path = os.path.join('recordings', audio_files[index])
    print(f"\n🎧 File {index + 1} of {len(audio_files)}: {audio_files[index]}")
    display(Audio(filename=file_path))

    speaker_input = widgets.Text(description='Speaker ID:')
    transcript_input = widgets.Text(description='Transcript:')
    button = widgets.Button(description='Save & Next')

    def on_click(b):
        labels.append([audio_files[index], speaker_input.value, transcript_input.value])
        button.close()
        label_next(index + 1)

    button.on_click(on_click)
    display(speaker_input, transcript_input, button)

label_next()'''
# Out:
# 🎧 File 1 of 2138: afrikaans1.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Text(value='', description='Speaker ID:')
# Text(value='', description='Transcript:')
# Button(description='Save & Next', style=ButtonStyle())

# %%
'''import csv

metadata_file = 'recordings/metadata.csv'

with open(metadata_file, mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['filename', 'speaker_id', 'transcript'])
    writer.writerows(labels)

print(f"✅ Metadata saved to {metadata_file}")'''
# Out:
# ✅ Metadata saved to recordings/metadata.csv

# %%
'''import pandas as pd

df = pd.read_csv('recordings/metadata.csv')
df.head()'''
# Out:
#          filename speaker_id  transcript
# 0  afrikaans1.wav      User1         NaN

# %% [markdown]
# # FOR A FOLDER

# %%
import os
import csv

base_dir = 'recordings'
metadata_file = os.path.join(base_dir, 'metadata.csv')

# Get list of .wav files
audio_files = [f for f in os.listdir(base_dir) if f.endswith('.wav')]

with open(metadata_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['filename', 'speaker_id', 'transcript'])

    for idx, file_name in enumerate(audio_files, start=1):
        speaker_id = f'speaker_{idx:03d}' 
        file_path = os.path.join(base_dir, file_name)
        writer.writerow([file_path, speaker_id, "N/A"])

print(f"✅ Metadata saved to {metadata_file}")
# Out:
# ✅ Metadata saved to recordings\metadata.csv

# %%
import pandas as pd

df = pd.read_csv('recordings/metadata.csv')
df.head(5)
# Out:
#                     filename   speaker_id  transcript
# 0  recordings\afrikaans1.wav  speaker_001         NaN
# 1  recordings\afrikaans2.wav  speaker_002         NaN
# 2  recordings\afrikaans3.wav  speaker_003         NaN
# 3  recordings\afrikaans4.wav  speaker_004         NaN
# 4  recordings\afrikaans5.wav  speaker_005         NaN

# %%
import pandas as pd

df = pd.read_csv('recordings/metadata.csv')
df.tail(5)
# Out:
#                     filename    speaker_id  transcript
# 2133  recordings\yoruba3.wav  speaker_2134         NaN
# 2134  recordings\yoruba4.wav  speaker_2135         NaN
# 2135  recordings\yoruba5.wav  speaker_2136         NaN
# 2136   recordings\yupik1.wav  speaker_2137         NaN
# 2137    recordings\zulu1.wav  speaker_2138         NaN
