# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pydub moviepy ffmpeg-python noisereduce speechbrain torchaudio torch pinecone sentencepiece --prefer-binary
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (0.25.1)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting noisereduce
#   Downloading noisereduce-3.0.3-py3-none-any.whl.metadata (14 kB)
# Collecting speechbrain
#   Downloading speechbrain-1.0.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting pinecone
#   Downloading pinecone-7.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.0.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from ffmpeg-python) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (3.10.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.5.1)
# Collecting hyperpyyaml (from speechbrain)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from speechbrain) (25.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from speechbrain) (0.33.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.7.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2025.7.14)
# Collecting pinecone-plugin-assistant<2.0.0,>=1.6.0 (from pinecone)
#   Downloading pinecone_plugin_assistant-1.7.0-py3-none-any.whl.metadata (28 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone) (2.5.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.3.0)
# Collecting packaging (from speechbrain)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->speechbrain) (6.0.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->speechbrain) (1.1.5)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (3.2.3)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Downloading speechbrain-1.0.3-py3-none-any.whl (864 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 864.1/864.1 kB 13.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.5 MB/s eta 0:00:00
# Downloading pinecone-7.3.0-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.6/587.6 kB 37.0 MB/s eta 0:00:00
# Downloading pinecone_plugin_assistant-1.7.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.0/240.0 kB 14.9 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.8 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 8.9 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 40.9 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, pinecone-plugin-interface, packaging, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ffmpeg-python, ruamel.yaml, pinecone-plugin-assistant, nvidia-cusparse-cu12, nvidia-cudnn-cu12, pinecone, nvidia-cusolver-cu12, noisereduce, hyperpyyaml, speechbrain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed ffmpeg-python-0.2.0 hyperpyyaml-1.2.2 noisereduce-3.0.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 packaging-24.2 pinecone-7.3.0 pinecone-plugin-assistant-1.7.0 pinecone-plugin-interface-0.0.7 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 speechbrain-1.0.3

# %%
import os
import uuid
import torch
import torchaudio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import noisereduce as nr
from pydub import AudioSegment
from speechbrain.pretrained import EncoderClassifier
import pinecone
from typing import List, Union, Dict, Any
import zipfile
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.metrics import precision_recall_fscore_support
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import euclidean, cosine
import itertools
import warnings
warnings.filterwarnings('ignore')
# Out:
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for _speechbrain_save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for _speechbrain_load
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for load
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for _save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for _recover
# /tmp/ipython-input-2-1084124052.py:11: UserWarning: Module 'speechbrain.pretrained' was deprecated, redirecting to 'speechbrain.inference'. Please update your script. This is a change from SpeechBrain 1.0. See: https://github.com/speechbrain/speechbrain/releases/tag/v1.0.0
#   from speechbrain.pretrained import EncoderClassifier

# %%
zip_path = '/content/drive/MyDrive/Capstone Reports/recordings.zip'
extract_path = '/content/sample_data/audio_samples/recordings'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Extracted to:", extract_path)
# Out:
# ✅ Extracted to: /content/sample_data/audio_samples/recordings

# %%
input_folder = "/content/sample_data/audio_samples/recordings/recordings"
output_wav_folder = "/content/sample_data/audio_samples/audio_wav"
embedding_output_path = "/content/sample_data/audio_samples/embeddings.csv"

# %%
def convert_to_wav_universal(input_folder, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    supported_formats = (".mp3", ".wav", ".ogg", ".oga", ".flac", ".mp4", ".m4a")

    for file_name in os.listdir(input_folder):
        input_path = os.path.join(input_folder, file_name)
        if file_name.lower().endswith(supported_formats):
            try:
                audio = AudioSegment.from_file(input_path)
                output_name = os.path.splitext(file_name)[0] + ".wav"
                output_path = os.path.join(output_folder, output_name)
                audio.export(output_path, format="wav")
                print(f"Converted: {file_name}")
            except Exception as e:
                print(f"Error converting {file_name}: {e}")
        else:
            print(f"Skipping unsupported file: {file_name}")

# %%
def audio_to_embedding_enhanced(audio_path):
    try:
        audio = AudioSegment.from_file(audio_path)
        normalized_audio = audio.apply_gain(-audio.dBFS)
        temp_path = audio_path.replace(".wav", "_normalized.wav")
        normalized_audio.export(temp_path, format="wav")

        waveform, sample_rate = torchaudio.load(temp_path)
        if waveform.shape[0] > 1:
            waveform = torch.mean(waveform, dim=0, keepdim=True)

        if sample_rate != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
            waveform = resampler(waveform)

        waveform_np = waveform.squeeze().cpu().numpy()
        denoised = nr.reduce_noise(y=waveform_np, sr=16000)
        waveform = torch.tensor(denoised).unsqueeze(0)

        vad = torchaudio.transforms.Vad(sample_rate=16000)
        waveform = vad(waveform)

        if waveform.numel() == 0:
            raise ValueError("No voiced segment found.")

        waveform = waveform / waveform.abs().max()
        if waveform.shape[1] < 16000:
            pad_amt = 16000 - waveform.shape[1]
            waveform = torch.nn.functional.pad(waveform, (0, pad_amt))

        waveform = waveform.unsqueeze(0).squeeze(1)
        embedding = model.encode_batch(waveform)

        os.remove(temp_path)
        return embedding.squeeze().numpy()

    except Exception as e:
        print(f"Error in audio_to_embedding_enhanced: {e}")
        return None

# %%
PINECONE_API_KEY = "pcsk_2yzKnb_DusX4M95CU1KTjQxkZFPdYWbtFghFc7kUD2cHzpUT4hWPLmMbPgEgT5NgoX3Fib"
PINECONE_ENV = "us-east-1"
INDEX_NAME = "voice-biometrics"
EMBEDDING_DIM = 192
UPSERT_BATCH_SIZE = 100

# %%
model = EncoderClassifier.from_hparams(
    source="speechbrain/spkrec-ecapa-voxceleb",
    savedir="pretrained_models/spkrec-ecapa-voxceleb",
    run_opts={"skip_vad": True}
)
# Out:
# INFO:speechbrain.utils.fetching:Fetch hyperparams.yaml: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# hyperparams.yaml: 0.00B [00:00, ?B/s]
# DEBUG:speechbrain.utils.fetching:Fetch: Local file found, creating symlink '/root/.cache/huggingface/hub/models--speechbrain--spkrec-ecapa-voxceleb/snapshots/0f99f2d0ebe89ac095bcc5903c4dd8f72b367286/hyperparams.yaml' -> '/content/pretrained_models/spkrec-ecapa-voxceleb/hyperparams.yaml'
# INFO:speechbrain.utils.fetching:Fetch custom.py: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for _save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for _load
# DEBUG:speechbrain.utils.checkpoints:Registered parameter transfer hook for _load
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint save hook for save
# DEBUG:speechbrain.utils.checkpoints:Registered checkpoint load hook for load_if_possible
# DEBUG:speechbrain.utils.parameter_transfer:Collecting files (or symlinks) for pretraining in pretrained_models/spkrec-ecapa-voxceleb.
# INFO:speechbrain.utils.fetching:Fetch embedding_model.ckpt: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# embedding_model.ckpt:   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# DEBUG:speechbrain.utils.fetching:Fetch: Local file found, creating symlink '/root/.cache/huggingface/hub/models--speechbrain--spkrec-ecapa-voxceleb/snapshots/0f99f2d0ebe89ac095bcc5903c4dd8f72b367286/embedding_model.ckpt' -> '/content/pretrained_models/spkrec-ecapa-voxceleb/embedding_model.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["embedding_model"] = /content/pretrained_models/spkrec-ecapa-voxceleb/embedding_model.ckpt
# INFO:speechbrain.utils.fetching:Fetch mean_var_norm_emb.ckpt: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# mean_var_norm_emb.ckpt:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# DEBUG:speechbrain.utils.fetching:Fetch: Local file found, creating symlink '/root/.cache/huggingface/hub/models--speechbrain--spkrec-ecapa-voxceleb/snapshots/0f99f2d0ebe89ac095bcc5903c4dd8f72b367286/mean_var_norm_emb.ckpt' -> '/content/pretrained_models/spkrec-ecapa-voxceleb/mean_var_norm_emb.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["mean_var_norm_emb"] = /content/pretrained_models/spkrec-ecapa-voxceleb/mean_var_norm_emb.ckpt
# INFO:speechbrain.utils.fetching:Fetch classifier.ckpt: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# classifier.ckpt:   0%|          | 0.00/5.53M [00:00<?, ?B/s]
# DEBUG:speechbrain.utils.fetching:Fetch: Local file found, creating symlink '/root/.cache/huggingface/hub/models--speechbrain--spkrec-ecapa-voxceleb/snapshots/0f99f2d0ebe89ac095bcc5903c4dd8f72b367286/classifier.ckpt' -> '/content/pretrained_models/spkrec-ecapa-voxceleb/classifier.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["classifier"] = /content/pretrained_models/spkrec-ecapa-voxceleb/classifier.ckpt
# INFO:speechbrain.utils.fetching:Fetch label_encoder.txt: Fetching from HuggingFace Hub 'speechbrain/spkrec-ecapa-voxceleb' if not cached
# label_encoder.txt: 0.00B [00:00, ?B/s]
# DEBUG:speechbrain.utils.fetching:Fetch: Local file found, creating symlink '/root/.cache/huggingface/hub/models--speechbrain--spkrec-ecapa-voxceleb/snapshots/0f99f2d0ebe89ac095bcc5903c4dd8f72b367286/label_encoder.txt' -> '/content/pretrained_models/spkrec-ecapa-voxceleb/label_encoder.ckpt'
# DEBUG:speechbrain.utils.parameter_transfer:Set local path in self.paths["label_encoder"] = /content/pretrained_models/spkrec-ecapa-voxceleb/label_encoder.ckpt
# INFO:speechbrain.utils.parameter_transfer:Loading pretrained files for: embedding_model, mean_var_norm_emb, classifier, label_encoder
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): embedding_model -> /content/pretrained_models/spkrec-ecapa-voxceleb/embedding_model.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): mean_var_norm_emb -> /content/pretrained_models/spkrec-ecapa-voxceleb/mean_var_norm_emb.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): classifier -> /content/pretrained_models/spkrec-ecapa-voxceleb/classifier.ckpt
# DEBUG:speechbrain.utils.parameter_transfer:Redirecting (loading from local path): label_encoder -> /content/pretrained_models/spkrec-ecapa-voxceleb/label_encoder.ckpt
# DEBUG:speechbrain.dataio.encoder:Loaded categorical encoding from /content/pretrained_models/spkrec-ecapa-voxceleb/label_encoder.ckpt

# %%
def init_pinecone():
    pc = pinecone.Pinecone(api_key=PINECONE_API_KEY, environment=PINECONE_ENV)
    existing_indexes = pc.list_indexes().names()
    if INDEX_NAME not in existing_indexes:
        pc.create_index(
            name=INDEX_NAME,
            dimension=EMBEDDING_DIM,
            metric="cosine",
            spec=pinecone.PodSpec(environment=PINECONE_ENV)
        )
    return pc.Index(INDEX_NAME)

# %%
def format_embeddings(vectors: List[np.ndarray], ids: List[str], metadata_list: List[dict] = None):
    return [
        (ids[i], vectors[i].tolist(), metadata_list[i] if metadata_list else None)
        for i in range(len(vectors))
    ]

# Keep track of the total number of upserted vectors across all calls
total_upserted_vectors = 0

def batch_upsert(index, data: List[Union[tuple, list]], batch_size: int = 10):
    global total_upserted_vectors
    for i in range(0, len(data), batch_size):
        index.upsert(vectors=data[i:i + batch_size])
        current_batch_size = len(data[i:i + batch_size])
        total_upserted_vectors += current_batch_size
        current_batch_number = (total_upserted_vectors + batch_size - 1) // batch_size # Calculate batch number based on total upserted
        print(f"✅ Upserted batch {current_batch_number} (Total vectors: {total_upserted_vectors})")

# %%
def process_audio_directory(input_folder, wav_folder, save_csv=True, upsert_to_pinecone=True, limit=None):
    convert_to_wav_universal(input_folder, wav_folder)

    embeddings = []
    ids = []
    metadata_list = []

    index = init_pinecone() if upsert_to_pinecone else None

    # Get list of all wav files
    wav_files = [f for f in os.listdir(wav_folder) if f.endswith(".wav")]

    # Apply limit if specified
    if limit is not None:
        wav_files = wav_files[:limit]

    # Process in batches
    batch_size = 100
    for i in range(0, len(wav_files), batch_size):
        batch_files = wav_files[i:i + batch_size]
        batch_embeddings = []
        batch_ids = []
        batch_metadata = []

        for fname in batch_files:
            path = os.path.join(wav_folder, fname)
            emb = audio_to_embedding_enhanced(path)
            if emb is not None:
                uid = str(uuid.uuid4())
                batch_embeddings.append(emb)
                batch_ids.append(uid)
                batch_metadata.append({"file_name": fname})
                print(f"✓ Processed: {fname}")

        embeddings.extend(batch_embeddings)
        ids.extend(batch_ids)
        metadata_list.extend(batch_metadata)

        if upsert_to_pinecone and batch_embeddings:
            formatted = format_embeddings(batch_embeddings, batch_ids, batch_metadata)
            batch_upsert(index, formatted, UPSERT_BATCH_SIZE)

    if save_csv and embeddings:
        df = pd.DataFrame(embeddings, index=ids)
        df.index.name = 'id'
        df.to_csv(embedding_output_path)
        print(f"📄 Embeddings saved to: {embedding_output_path}")

    return embeddings, ids, metadata_list

# %%
def similarity_search(audio_path: str, index, top_k: int = 5):
    query_embedding = audio_to_embedding_enhanced(audio_path)
    return index.query(vector=query_embedding.tolist(), top_k=top_k, include_metadata=True)

def test_similarity_search(audio_path: str, index, top_k: int = 5):
    print(f"\n🔍 Similarity Search for: {os.path.basename(audio_path)}")
    try:
        results = similarity_search(audio_path, index, top_k)
        for i, match in enumerate(results['matches'], 1):
            metadata = match.get('metadata', {})
            print(f"{i}. {metadata.get('file_name', 'Unknown')} (Score: {match['score']:.4f})")
    except Exception as e:
        print(f"❌ Error during search: {e}")

# %%
# Process and upsert a limited number of audio files
embeddings, ids, metadata_list = process_audio_directory(
    input_folder,
    output_wav_folder,
    save_csv=True,         # Set to True if you want to save embeddings to a CSV
    upsert_to_pinecone=True, # Set to True to upsert to Pinecone
    limit=100              # Set a number if you want to process only a limited number of files
)
# Out:
# Converted: bulgarian8.mp3
# Converted: english417.mp3
# Converted: dutch11.mp3
# Converted: english405.mp3
# Converted: english387.mp3
# Converted: serbian15.wav
# Converted: arabic9.wav
# Converted: spanish83.wav
# Converted: albanian2.mp3
# Converted: french2.mp3
# Converted: kikongo1.mp3
# Converted: polish30.wav
# Converted: hindi14.mp3
# Converted: amharic14.wav
# Converted: english173.mp3
# Converted: dutch15.wav
# Converted: russian40.mp3
# Converted: english551.wav
# Converted: english244.mp3
# Converted: english306.mp3
# Converted: dutch6.mp3
# Converted: italian22.mp3
# Converted: taiwanese6.mp3
# Converted: spanish97.mp3
# Converted: swedish17.mp3
# Converted: miskito1.wav
# Converted: japanese21.mp3
# Converted: amharic2.wav
# Converted: english187.wav
# Converted: english557.mp3
# Converted: wolof3.mp3
# Converted: mandarin7.wav
# Converted: amharic20.wav
# Converted: amharic10.wav
# Converted: norwegian4.wav
# Converted: swedish20.mp3
# Converted: arabic40.wav
# Converted: bengali3.mp3
# Converted: arabic36.wav
# Converted: spanish103.wav
# Converted: pulaar3.wav
# Converted: english295.mp3
# Converted: mandingo1.wav
# Converted: spanish44.wav
# Converted: uyghur2.mp3
# Converted: yiddish1.wav
# Converted: spanish5.wav
# Converted: english238.mp3
# Converted: english135.mp3
# Converted: english283.wav
# Converted: russian3.wav
# Converted: german17.wav
# Converted: english214.mp3
# Converted: bosnian8.wav
# Converted: hebrew2.wav
# Converted: urdu6.mp3
# Converted: amharic16.mp3
# Converted: finnish2.mp3
# Converted: mongolian8.mp3
# Converted: kikuyu3.wav
# Converted: armenian3.mp3
# Converted: serbian16.mp3
# Converted: sa'a1.mp3
# Converted: english384.mp3
# Converted: dari4.mp3
# Converted: english185.mp3
# Converted: portuguese25.wav
# Converted: indonesian8.wav
# Converted: farsi3.mp3
# Converted: english236.wav
# Converted: mandarin11.wav
# Converted: georgian4.wav
# Converted: english193.wav
# Converted: english6.mp3
# Converted: twi4.mp3
# Converted: tamil1.mp3
# Converted: spanish5.mp3
# Converted: polish32.wav
# Converted: dari5.mp3
# Converted: macedonian25.wav
# Converted: english232.wav
# Converted: farsi18.mp3
# Converted: spanish142.wav
# Converted: nepali3.wav
# Converted: spanish133.wav
# Converted: hungarian4.mp3
# Converted: dutch39.mp3
# Converted: russian27.wav
# Converted: korean16.mp3
# Converted: malayalam2.wav
# Converted: italian9.wav
# Converted: english496.mp3
# Converted: german5.mp3
# Converted: garifuna2.mp3
# Converted: mandarin37.mp3
# Converted: malayalam3.wav
# Converted: burmese2.wav
# Converted: romanian4.mp3
# Converted: english380.mp3
# Converted: thai9.mp3
# Converted: kurdish3.wav
# Converted: english313.wav
# Converted: tamil6.mp3
# Converted: english139.wav
# Converted: portuguese1.wav
# Converted: afrikaans3.mp3
# Converted: spanish71.wav
# Converted: dutch21.mp3
# Converted: english116.mp3
# Converted: bambara5.wav
# Converted: english210.mp3
# Converted: arabic60.mp3
# Converted: czech5.wav
# Converted: english511.wav
# Converted: tamil2.wav
# Converted: korean5.mp3
# Converted: spanish143.mp3
# Converted: azerbaijani1.mp3
# Converted: english52.mp3
# Converted: kiswahili7.mp3
# Converted: english356.mp3
# Converted: korean28.mp3
# Converted: english477.mp3
# Converted: english155.wav
# Converted: croatian4.wav
# Converted: tswana1.wav
# Converted: german26.wav
# Converted: bengali4.mp3
# Converted: english188.mp3
# Converted: english97.mp3
# Converted: danish3.mp3
# Converted: korean9.mp3
# Converted: japanese17.wav
# Converted: polish32.mp3
# Converted: portuguese11.mp3
# Converted: hebrew7.mp3
# Converted: newari1.mp3
# Converted: gan1.mp3
# Converted: tigrigna5.mp3
# Converted: english437.mp3
# Converted: spanish66.wav
# Converted: slovak3.mp3
# Converted: gujarati1.wav
# Converted: thai1.mp3
# Converted: english226.mp3
# Converted: english574.wav
# Converted: gujarati2.mp3
# Converted: turkish22.wav
# Converted: konkani1.wav
# Converted: oriya1.mp3
# Converted: macedonian12.wav
# Converted: english94.mp3
# Converted: korean39.mp3
# Converted: english303.mp3
# Converted: turkish32.mp3
# Converted: english570.mp3
# Converted: french57.mp3
# Converted: polish9.mp3
# Converted: romanian2.mp3
# Converted: arabic19.mp3
# Converted: mandarin56.mp3
# Converted: italian27.wav
# Converted: marathi2.wav
# Converted: bengali11.wav
# Converted: carolinian1.wav
# Converted: dutch21.wav
# Converted: mandarin9.wav
# Converted: english278.mp3
# Converted: danish6.mp3
# Converted: urdu11.mp3
# Converted: bambara2.wav
# Converted: english439.wav
# Converted: english63.mp3
# Converted: indonesian6.mp3
# Converted: english328.wav
# Converted: spanish16.mp3
# Converted: danish5.mp3
# Converted: korean30.mp3
# Converted: english346.wav
# Converted: lithuanian6.wav
# Converted: farsi2.wav
# Converted: english517.wav
# Converted: arabic44.wav
# Converted: english213.wav
# Converted: romanian6.wav
# Converted: spanish26.wav
# Converted: english527.mp3
# Converted: ukrainian9.mp3
# Converted: russian38.mp3
# Converted: arabic86.mp3
# Converted: kikuyu3.mp3
# Converted: kikongo2.wav
# Converted: kalanga1.mp3
# Converted: spanish86.wav
# Converted: english550.mp3
# Converted: farsi19.wav
# Converted: moore1.mp3
# Converted: english364.wav
# Converted: russian46.wav
# Converted: italian23.mp3
# Converted: portuguese44.wav
# Converted: italian13.mp3
# Converted: serbian13.mp3
# Converted: nepali5.mp3
# Converted: english102.wav
# Converted: norwegian4.mp3
# Converted: english21.mp3
# Converted: russian19.wav
# Converted: english505.mp3
# Converted: wolof1.mp3
# Converted: hakka1.wav
# Converted: english394.mp3
# Converted: english75.wav
# Converted: polish24.mp3
# Converted: polish14.wav
# Converted: english508.mp3
# Converted: amharic12.wav
# Converted: mandarin45.wav
# Converted: dutch1.wav
# Converted: english4.wav
# Converted: croatian7.mp3
# Converted: english20.wav
# Converted: english448.wav
# Converted: dutch20.wav
# Converted: urdu14.mp3
# Converted: farsi2.mp3
# Converted: english80.mp3
# Converted: english12.wav
# Converted: uyghur1.mp3
# Converted: spanish153.mp3
# Converted: macedonian26.wav
# Converted: mandarin58.mp3
# Converted: french34.wav
# Converted: arabic91.wav
# Converted: french44.mp3
# Converted: english376.mp3
# Converted: tagalog5.mp3
# Converted: spanish82.mp3
# Converted: tigrigna5.wav
# Converted: macedonian12.mp3
# Converted: bulgarian4.wav
# Converted: english327.wav
# Converted: english57.wav
# Converted: turkish31.wav
# Converted: urdu2.wav
# Converted: english532.mp3
# Converted: korean2.wav
# Converted: sicilian1.wav
# Converted: arabic57.mp3
# Converted: hindi12.mp3
# Converted: mandarin10.wav
# Converted: portuguese19.wav
# Converted: mandarin44.mp3
# Converted: english170.wav
# Converted: french55.wav
# Converted: dutch8.mp3
# Converted: swedish18.wav
# Converted: vietnamese19.mp3
# Converted: spanish77.wav
# Converted: japanese9.mp3
# Converted: french45.wav
# Converted: english130.mp3
# Converted: spanish22.wav
# Converted: lao2.wav
# Converted: malayalam1.mp3
# Converted: romanian3.wav
# Converted: english545.wav
# Converted: dutch8.wav
# Converted: english247.mp3
# Converted: english63.wav
# Converted: chaldean1.mp3
# Converted: mongolian4.wav
# Converted: spanish36.mp3
# Converted: korean11.wav
# Converted: russian42.wav
# Converted: english352.mp3
# Converted: english376.wav
# Converted: belarusan1.wav
# Converted: english239.mp3
# Converted: german29.mp3
# Converted: arabic55.wav
# Converted: english272.wav
# Converted: gujarati9.mp3
# Converted: english300.mp3
# Converted: arabic11.wav
# Converted: korean20.wav
# Converted: taiwanese8.wav
# Converted: english206.wav
# Converted: english256.mp3
# Converted: tagalog18.wav
# Converted: mandarin49.mp3
# Converted: english539.mp3
# Converted: english222.mp3
# Converted: english182.wav
# Converted: finnish7.mp3
# Converted: english379.wav
# Converted: arabic25.mp3
# Converted: cantonese4.mp3
# Converted: dutch45.mp3
# Converted: french49.mp3
# Converted: english121.wav
# Converted: russian33.mp3
# Converted: spanish4.wav
# Converted: turkish13.wav
# Converted: spanish150.mp3
# Converted: english68.wav
# Converted: vietnamese14.wav
# Converted: twi1.mp3
# Converted: spanish143.wav
# Converted: macedonian20.mp3
# Converted: french49.wav
# Converted: mandarin62.mp3
# Converted: indonesian7.wav
# Converted: polish27.mp3
# Converted: spanish84.wav
# Converted: arabic85.wav
# Converted: english531.wav
# Converted: english495.wav
# Converted: spanish161.wav
# Converted: english518.wav
# Converted: french12.wav
# Converted: english148.wav
# Converted: finnish6.wav
# Converted: english514.mp3
# Converted: thai15.wav
# Converted: tagalog8.mp3
# Converted: polish12.wav
# Converted: spanish133.mp3
# Converted: mongolian3.wav
# Converted: yiddish4.wav
# Converted: tagalog10.mp3
# Converted: arabic75.mp3
# Converted: spanish12.wav
# Converted: english556.mp3
# Converted: afrikaans4.wav
# Converted: kurdish2.wav
# Converted: english96.wav
# Converted: english416.mp3
# Converted: english101.mp3
# Converted: turkish37.wav
# Converted: english224.wav
# Converted: korean41.mp3
# Converted: vlaams4.mp3
# Converted: urdu8.mp3
# Converted: english319.mp3
# Converted: english132.mp3
# Converted: english414.mp3
# Converted: cantonese4.wav
# Converted: english50.wav
# Converted: french61.mp3
# Converted: english402.wav
# Converted: bulgarian14.wav
# Converted: spanish72.wav
# Converted: nepali8.mp3
# Converted: rotuman2.mp3
# Converted: mandarin47.wav
# Converted: english121.mp3
# Converted: greek4.wav
# Converted: english200.mp3
# Converted: spanish64.wav
# Converted: english26.wav
# Converted: arabic48.wav
# Converted: synthesized2.wav
# Converted: swedish5.mp3
# Converted: english468.wav
# Converted: english559.wav
# Converted: english266.wav
# Converted: tibetan3.mp3
# Converted: hungarian5.wav
# Converted: serbian1.mp3
# Converted: slovak1.wav
# Converted: igbo3.wav
# Converted: spanish79.mp3
# Converted: english305.mp3
# Converted: ukrainian2.mp3
# Converted: english320.wav
# Converted: english367.wav
# Converted: spanish135.mp3
# Converted: romanian9.wav
# Converted: japanese8.wav
# Converted: hindi10.wav
# Converted: english76.mp3
# Converted: english503.wav
# Converted: vietnamese21.mp3
# Converted: french33.wav
# Converted: english231.wav
# Converted: french53.mp3
# Converted: korean39.wav
# Converted: english397.mp3
# Converted: bafang1.wav
# Converted: spanish89.wav
# Converted: english22.wav
# Converted: english447.mp3
# Converted: arabic95.wav
# Converted: krio2.mp3
# Converted: spanish137.wav
# Converted: arabic18.wav
# Converted: english393.mp3
# Converted: urdu7.mp3
# Converted: akan1.wav
# Converted: korean16.wav
# Converted: swedish10.wav
# Converted: german9.mp3
# Converted: english67.wav
# Converted: arabic20.wav
# Converted: korean40.wav
# Converted: french13.wav
# Converted: bengali12.wav
# Converted: spanish150.wav
# Converted: english194.wav
# Converted: satawalese2.mp3
# Converted: ibibio1.mp3
# Converted: hindi15.mp3
# Converted: dari1.wav
# Converted: english417.wav
# Converted: japanese6.mp3
# Converted: albanian7.wav
# Converted: french17.mp3
# Converted: english486.mp3
# Converted: english206.mp3
# Converted: english574.mp3
# Converted: bulgarian12.wav
# Converted: thai7.wav
# Converted: spanish47.mp3
# Converted: oromo3.mp3
# Converted: french48.mp3
# Converted: chaldean2.wav
# Converted: english455.mp3
# Converted: cantonese14.wav
# Converted: tigrigna6.wav
# Converted: swedish7.wav
# Converted: twi5.wav
# Converted: english534.mp3
# Converted: uzbek1.mp3
# Converted: indonesian2.mp3
# Converted: english420.wav
# Converted: mandarin42.mp3
# Converted: arabic15.mp3
# Converted: english538.wav
# Converted: english60.mp3
# Converted: english169.mp3
# Converted: spanish85.wav
# Converted: amharic2.mp3
# Converted: greek15.wav
# Converted: english324.mp3
# Converted: english551.mp3
# Converted: tamil5.mp3
# Converted: italian31.mp3
# Converted: luo2.mp3
# Converted: russian19.mp3
# Converted: korean46.wav
# Converted: hindi14.wav
# Converted: punjabi10.mp3
# Converted: russian23.mp3
# Converted: ga2.mp3
# Converted: french32.mp3
# Converted: tagalog1.mp3
# Converted: cantonese3.wav
# Converted: english28.mp3
# Converted: bosnian4.wav
# Converted: arabic41.mp3
# Converted: swedish18.mp3
# Converted: mandarin14.wav
# Converted: spanish34.mp3
# Converted: khmer2.mp3
# Converted: english240.mp3
# Converted: hindi3.wav
# Converted: spanish140.wav
# Converted: malagasy1.wav
# Converted: vietnamese5.mp3
# Converted: polish11.wav
# Converted: spanish39.wav
# Converted: korean45.mp3
# Converted: nepali12.wav
# Converted: spanish47.wav
# Converted: shona1.mp3
# Converted: lao1.mp3
# Converted: afrikaans4.mp3
# Converted: polish23.wav
# Converted: french48.wav
# Converted: norwegian6.wav
# Converted: spanish157.wav
# Converted: portuguese36.mp3
# Converted: english9.wav
# Converted: hebrew1.mp3
# Converted: english312.mp3
# Converted: arabic3.wav
# Converted: yiddish5.mp3
# Converted: mandarin4.mp3
# Converted: french14.mp3
# Converted: luo1.mp3
# Converted: italian19.mp3
# Converted: turkish10.mp3
# Converted: english469.wav
# Converted: hausa8.wav
# Converted: vietnamese22.wav
# Converted: english556.wav
# Converted: hindi18.mp3
# Converted: french20.wav
# Converted: serbian2.wav
# Converted: macedonian24.wav
# Converted: english450.wav
# Converted: yoruba5.mp3
# Converted: tamil3.mp3
# Converted: japanese3.wav
# Converted: bosnian2.wav
# Converted: arabic29.wav
# Converted: english235.wav
# Converted: portuguese27.mp3
# Converted: spanish158.wav
# Converted: mongolian2.wav
# Converted: portuguese31.wav
# Converted: vietnamese18.mp3
# Converted: ibibio1.wav
# Converted: french27.mp3
# Converted: arabic66.mp3
# Converted: mandarin26.mp3
# Converted: afrikaans1.wav
# Converted: english446.wav
# Converted: english503.mp3
# Converted: french53.wav
# Converted: dutch37.mp3
# Converted: romanian16.mp3
# Converted: english454.mp3
# Converted: gujarati8.mp3
# Converted: russian20.mp3
# Converted: english533.wav
# Converted: korean48.wav
# Converted: kurdish8.mp3
# Converted: finnish5.mp3
# Converted: english519.wav
# Converted: portuguese8.mp3
# Converted: spanish69.wav
# Converted: english244.wav
# Converted: catalan2.wav
# Converted: arabic80.wav
# Converted: english552.mp3
# Converted: portuguese43.mp3
# Converted: portuguese34.mp3
# Converted: armenian8.mp3
# Converted: arabic72.wav
# Converted: english562.wav
# Converted: turkish36.wav
# Converted: georgian5.mp3
# Converted: farsi23.mp3
# Converted: english395.mp3
# Converted: farsi12.wav
# Converted: hebrew1.wav
# Converted: tagalog12.wav
# Converted: albanian8.wav
# Converted: finnish8.wav
# Converted: lao2.mp3
# Converted: spanish3.wav
# Converted: english157.mp3
# Converted: english178.wav
# Converted: pashto2.mp3
# Converted: serbian18.mp3
# Converted: spanish106.mp3
# Converted: bengali9.wav
# Converted: english405.wav
# Converted: polish21.wav
# Converted: english115.wav
# Converted: vietnamese3.mp3
# Converted: english208.wav
# Converted: english478.wav
# Converted: english397.wav
# Converted: swedish11.wav
# Converted: english513.wav
# Converted: spanish109.wav
# Converted: russian31.wav
# Converted: croatian8.wav
# Converted: english43.wav
# Converted: farsi9.mp3
# Converted: french12.mp3
# Converted: spanish94.mp3
# Converted: english269.mp3
# Converted: khmer7.mp3
# Converted: french60.mp3
# Converted: english145.mp3
# Converted: romanian10.mp3
# Converted: russian20.wav
# Converted: dutch42.mp3
# Converted: english524.mp3
# Converted: turkish24.wav
# Converted: spanish22.mp3
# Converted: english106.mp3
# Converted: english309.wav
# Converted: english49.wav
# Converted: english377.mp3
# Converted: uyghur3.mp3
# Converted: mortlockese1.wav
# Converted: english413.mp3
# Converted: english97.wav
# Converted: german12.mp3
# Converted: bulgarian18.mp3
# Converted: pashto5.mp3
# Converted: english117.mp3
# Converted: punjabi8.wav
# Converted: polish13.wav
# Converted: english44.wav
# Converted: mandarin46.wav
# Converted: cantonese21.wav
# Converted: english334.wav
# Converted: indonesian3.wav
# Converted: chittagonian1.wav
# Converted: mandarin53.wav
# Converted: punjabi1.mp3
# Converted: sundanese1.mp3
# Converted: german20.mp3
# Converted: english124.wav
# Converted: yoruba3.mp3
# Converted: rotuman2.wav
# Converted: english510.wav
# Converted: amharic1.wav
# Converted: sardinian1.mp3
# Converted: tajiki1.wav
# Converted: arabic46.mp3
# Converted: english174.mp3
# Converted: xiang3.wav
# Converted: mandarin48.wav
# Converted: kikuyu1.wav
# Converted: macedonian6.mp3
# Converted: english390.wav
# Converted: english276.wav
# Converted: german19.mp3
# Converted: kambaata3.mp3
# Converted: korean50.wav
# Converted: english260.mp3
# Converted: spanish73.mp3
# Converted: english381.mp3
# Converted: italian11.wav
# Converted: english4.mp3
# Converted: spanish99.wav
# Converted: gujarati1.mp3
# Converted: portuguese6.wav
# Converted: italian4.mp3
# Converted: english234.wav
# Converted: nuer1.wav
# Converted: vietnamese4.mp3
# Converted: romanian12.wav
# Converted: miskito11.mp3
# Converted: english520.mp3
# Converted: english430.wav
# Converted: english241.mp3
# Converted: spanish120.wav
# Converted: japanese11.wav
# Converted: ukrainian10.mp3
# Converted: english48.mp3
# Converted: bafang1.mp3
# Converted: tigrigna2.wav
# Converted: mandarin39.wav
# Converted: arabic21.mp3
# Converted: english34.mp3
# Converted: french39.wav
# Converted: spanish32.mp3
# Converted: english5.mp3
# Converted: french41.mp3
# Converted: english271.wav
# Converted: hausa4.wav
# Converted: amharic16.wav
# Converted: greek12.mp3
# Converted: english310.wav
# Converted: german2.wav
# Converted: english573.wav
# Converted: english549.mp3
# Converted: arabic54.mp3
# Converted: twi6.wav
# Converted: english160.mp3
# Converted: turkish31.mp3
# Converted: arabic21.wav
# Converted: english471.wav
# Converted: catalan1.mp3
# Converted: arabic32.wav
# Converted: fijian1.wav
# Converted: norwegian6.mp3
# Converted: spanish147.wav
# Converted: tagalog3.wav
# Converted: mandarin57.mp3
# Converted: croatian1.mp3
# Converted: wolof6.wav
# Converted: hausa1.mp3
# Converted: english324.wav
# Converted: dutch33.mp3
# Converted: english517.mp3
# Converted: italian14.wav
# Converted: thai10.wav
# Converted: turkish29.wav
# Converted: gujarati7.mp3
# Converted: azerbaijani1.wav
# Converted: cantonese23.wav
# Converted: turkish34.mp3
# Converted: tamil4.mp3
# Converted: marathi3.wav
# Converted: italian14.mp3
# Converted: english378.mp3
# Converted: portuguese33.mp3
# Converted: afrikaans5.wav
# Converted: arabic37.mp3
# Converted: punjabi6.mp3
# Converted: english484.mp3
# Converted: english375.wav
# Converted: spanish110.mp3
# Converted: farsi19.mp3
# Converted: english47.mp3
# Converted: french23.wav
# Converted: romanian19.mp3
# Converted: german36.mp3
# Converted: english464.mp3
# Converted: english176.mp3
# Converted: english227.mp3
# Converted: german32.wav
# Converted: hungarian7.mp3
# Converted: spanish94.wav
# Converted: english401.mp3
# Converted: english56.wav
# Converted: icelandic1.mp3
# Converted: ukrainian1.wav
# Converted: english514.wav
# Converted: german14.wav
# Converted: thai3.wav
# Converted: spanish79.wav
# Converted: vietnamese11.wav
# Converted: mankanya1.mp3
# Converted: farsi8.mp3
# Converted: mandarin2.mp3
# Converted: farsi10.wav
# Converted: igbo1.wav
# Converted: english472.mp3
# Converted: english120.wav
# Converted: mongolian6.mp3
# Converted: arabic90.wav
# Converted: english384.wav
# Converted: spanish26.mp3
# Converted: sinhala6.mp3
# Converted: japanese1.mp3
# Converted: vietnamese15.mp3
# Converted: greek6.mp3
# Converted: garifuna1.mp3
# Converted: chichewa1.mp3
# Converted: polish3.mp3
# Converted: cantonese12.wav
# Converted: german30.mp3
# Converted: spanish101.mp3
# Converted: spanish121.wav
# Converted: farsi16.mp3
# Converted: armenian6.mp3
# Converted: turkish9.mp3
# Converted: english202.mp3
# Converted: serbian3.mp3
# Converted: mandarin50.mp3
# Converted: english532.wav
# Converted: german28.wav
# Converted: spanish52.wav
# Converted: mandarin6.mp3
# Converted: frisian1.wav
# Converted: romanian11.wav
# Converted: japanese18.mp3
# Converted: portuguese2.mp3
# Converted: vietnamese7.wav
# Converted: czech7.mp3
# Converted: arabic77.mp3
# Converted: gujarati3.wav
# Converted: korean21.mp3
# Converted: english437.wav
# Converted: romanian13.mp3
# Converted: indonesian5.mp3
# Converted: english554.wav
# Converted: macedonian2.wav
# Converted: spanish161.mp3
# Converted: arabic71.mp3
# Converted: twi2.wav
# Converted: hindi1.wav
# Converted: basque1.mp3
# Converted: italian5.mp3
# Converted: bengali7.mp3
# Converted: xiang4.wav
# Converted: english221.mp3
# Converted: marathi1.wav
# Converted: russian25.wav
# Converted: arabic78.wav
# Converted: portuguese38.mp3
# Converted: slovak4.mp3
# Converted: spanish155.wav
# Converted: spanish126.mp3
# Converted: english540.mp3
# Converted: portuguese46.wav
# Converted: russian46.mp3
# Converted: vietnamese15.wav
# Converted: english15.wav
# Converted: turkish36.mp3
# Converted: farsi15.mp3
# Converted: english568.mp3
# Converted: turkish14.wav
# Converted: arabic42.wav
# Converted: english406.mp3
# Converted: arabic64.wav
# Converted: english420.mp3
# Converted: english305.wav
# Converted: portuguese7.mp3
# Converted: english513.mp3
# Converted: english104.mp3
# Converted: taishan1.mp3
# Converted: german36.wav
# Converted: english59.mp3
# Converted: kiswahili2.mp3
# Converted: english451.mp3
# Converted: swedish12.wav
# Converted: wolof2.mp3
# Converted: mandarin43.wav
# Converted: portuguese41.wav
# Converted: maltese2.mp3
# Converted: english170.mp3
# Converted: kiswahili5.wav
# Converted: dutch15.mp3
# Converted: english3.mp3
# Converted: portuguese46.mp3
# Converted: english332.wav
# Converted: english383.wav
# Converted: polish7.wav
# Converted: spanish7.wav
# Converted: english78.mp3
# Converted: english267.wav
# Converted: english31.mp3
# Converted: mandarin5.mp3
# Converted: polish1.mp3
# Converted: indonesian3.mp3
# Converted: spanish55.mp3
# Converted: english150.mp3
# Converted: sardinian1.wav
# Converted: mandarin55.mp3
# Converted: french3.mp3
# Converted: english349.wav
# Converted: english189.wav
# Converted: english269.wav
# Converted: english233.mp3
# Converted: hebrew4.mp3
# Converted: czech8.mp3
# Converted: uzbek4.wav
# Converted: cantonese2.wav
# Converted: mandarin39.mp3
# Converted: english25.mp3
# Converted: mongolian9.wav
# Converted: german34.wav
# Converted: spanish144.mp3
# Converted: french1.mp3
# Converted: english88.wav
# Converted: portuguese19.mp3
# Converted: english578.wav
# Converted: spanish122.mp3
# Converted: kikuyu4.mp3
# Converted: english8.mp3
# Converted: amharic3.wav
# Converted: cantonese17.mp3
# Converted: english418.wav
# Converted: dutch41.wav
# Converted: pashto8.mp3
# Converted: spanish113.wav
# Converted: arabic55.mp3
# Converted: spanish58.mp3
# Converted: finnish4.wav
# Converted: japanese2.mp3
# Converted: danish7.wav
# Converted: english19.wav
# Converted: albanian3.mp3
# Converted: english466.mp3
# Converted: spanish74.mp3
# Converted: english118.mp3
# Converted: pashto4.wav
# Converted: french37.mp3
# Converted: bosnian9.wav
# Converted: xiang1.wav
# Converted: spanish81.mp3
# Converted: italian4.wav
# Converted: bulgarian16.mp3
# Converted: english460.mp3
# Converted: english272.mp3
# Converted: cantonese3.mp3
# Converted: russian2.mp3
# Converted: spanish2.mp3
# Converted: rwanda1.mp3
# Converted: english336.wav
# Converted: chamorro1.wav
# Converted: farsi20.wav
# Converted: slovak2.wav
# Converted: english78.wav
# Converted: english476.mp3
# Converted: german23.wav
# Converted: bulgarian7.mp3
# Converted: russian42.mp3
# Converted: kiswahili2.wav
# Converted: arabic44.mp3
# Converted: zulu1.wav
# Converted: french28.mp3
# Converted: albanian5.wav
# Converted: miskito9.wav
# Converted: japanese10.wav
# Converted: english482.wav
# Converted: twi2.mp3
# Converted: kurdish6.mp3
# Converted: tagalog15.mp3
# Converted: english264.wav
# Converted: english133.mp3
# Converted: turkish34.wav
# Converted: english559.mp3
# Converted: english318.mp3
# Converted: spanish58.wav
# Converted: english318.wav
# Converted: spanish18.wav
# Converted: english201.mp3
# Converted: english16.mp3
# Converted: shilluk1.mp3
# Converted: english219.mp3
# Converted: krio6.mp3
# Converted: spanish20.wav
# Converted: english541.wav
# Converted: nepali5.wav
# Converted: french10.wav
# Converted: bengali17.wav
# Converted: danish4.wav
# Converted: serbian5.wav
# Converted: english164.wav
# Converted: arabic14.wav
# Converted: french51.mp3
# Converted: english47.wav
# Converted: english278.wav
# Converted: english82.wav
# Converted: swedish20.wav
# Converted: english262.wav
# Converted: english75.mp3
# Converted: portuguese37.wav
# Converted: english488.mp3
# Converted: arabic1.wav
# Converted: pashto4.mp3
# Converted: dutch16.mp3
# Converted: english440.mp3
# Converted: dutch5.mp3
# Converted: english87.mp3
# Converted: russian30.wav
# Converted: dutch18.wav
# Converted: english421.mp3
# Converted: romanian3.mp3
# Converted: punjabi9.mp3
# Converted: spanish98.wav
# Converted: farsi4.wav
# Converted: english411.mp3
# Converted: hadiyya2.mp3
# Converted: bulgarian8.wav
# Converted: vietnamese21.wav
# Converted: ga4.mp3
# Converted: russian40.wav
# Converted: english314.wav
# Converted: pulaar2.wav
# Converted: english487.mp3
# Converted: mandarin15.mp3
# Converted: english501.wav
# Converted: french41.wav
# Converted: oromo2.wav
# Converted: tagalog6.wav
# Converted: english329.wav
# Converted: bavarian2.wav
# Converted: english341.wav
# Converted: english522.wav
# Converted: urdu9.mp3
# Converted: spanish49.mp3
# Converted: english13.wav
# Converted: bavarian2.mp3
# Converted: albanian9.wav
# Converted: english151.wav
# Converted: kazakh1.wav
# Converted: cantonese10.wav
# Converted: english429.mp3
# Converted: teochew1.mp3
# Converted: portuguese48.wav
# Converted: german27.wav
# Converted: english565.mp3
# Converted: mizo1.mp3
# Converted: luo1.wav
# Converted: kurdish7.mp3
# Converted: italian12.wav
# Converted: armenian1.mp3
# Converted: english257.wav
# Converted: uzbek4.mp3
# Converted: greek13.wav
# Converted: swedish14.wav
# Converted: japanese13.wav
# Converted: english459.wav
# Converted: rwanda1.wav
# Converted: english242.wav
# Converted: english23.mp3
# Converted: italian20.wav
# Converted: hindi6.mp3
# Converted: danish6.wav
# Converted: english161.mp3
# Converted: english369.mp3
# Converted: german1.mp3
# Converted: spanish14.mp3
# Converted: gujarati4.mp3
# Converted: french58.mp3
# Converted: krio4.mp3
# Converted: portuguese45.wav
# Converted: english347.wav
# Converted: english449.wav
# Converted: arabic90.mp3
# Converted: english507.mp3
# Converted: english24.mp3
# Converted: greek4.mp3
# Converted: mandarin32.mp3
# Converted: dutch44.mp3
# Converted: english33.mp3
# Converted: norwegian1.wav
# Converted: greek8.wav
# Converted: papiamentu2.wav
# Converted: french5.mp3
# Converted: miskito1.mp3
# Converted: spanish25.mp3
# Converted: arabic11.mp3
# Converted: english339.mp3
# Converted: korean50.mp3
# Converted: lithuanian2.mp3
# Converted: russian17.wav
# Converted: arabic4.wav
# Converted: english576.wav
# Converted: uzbek2.wav
# Converted: turkish20.wav
# Converted: tagalog4.mp3
# Converted: french9.wav
# Converted: somali5.wav
# Converted: english463.wav
# Converted: english565.wav
# Converted: pulaar1.wav
# Converted: english45.mp3
# Converted: english246.mp3
# Converted: korean3.wav
# Converted: temne1.mp3
# Converted: urdu7.wav
# Converted: spanish142.mp3
# Converted: german7.wav
# Converted: spanish91.wav
# Converted: tigrigna1.wav
# Converted: taiwanese6.wav
# Converted: uzbek3.mp3
# Converted: english526.wav
# Converted: english310.mp3
# Converted: khmer4.wav
# Converted: french16.mp3
# Converted: albanian1.mp3
# Converted: armenian3.wav
# Converted: english558.wav
# Converted: english570.wav
# Converted: japanese5.mp3
# Converted: mandingo1.mp3
# Converted: serbian17.wav
# Converted: arabic81.mp3
# Converted: english189.mp3
# Converted: english126.wav
# Converted: english268.mp3
# Converted: english255.wav
# Converted: russian38.wav
# Converted: english106.wav
# Converted: english443.wav
# Converted: hebrew4.wav
# Converted: english433.mp3
# Converted: french14.wav
# Converted: mandarin41.wav
# Converted: croatian3.mp3
# Converted: english368.mp3
# Converted: polish13.mp3
# Converted: turkish33.wav
# Converted: english149.mp3
# Converted: arabic79.wav
# Converted: kiswahili6.mp3
# Converted: filipino1.mp3
# Converted: english560.wav
# Converted: mandinka1.mp3
# Converted: english553.mp3
# Converted: vietnamese5.wav
# Converted: german10.mp3
# Converted: german31.wav
# Converted: spanish14.wav
# Converted: taiwanese3.mp3
# Converted: portuguese21.mp3
# Converted: arabic76.mp3
# Converted: romanian15.mp3
# Converted: spanish131.wav
# Converted: english86.mp3
# Converted: hausa4.mp3
# Converted: vietnamese12.wav
# Converted: english21.wav
# Converted: arabic60.wav
# Converted: english416.wav
# Converted: arabic5.mp3
# Converted: ga5.mp3
# Converted: hindi17.wav
# Converted: somali3.wav
# Converted: farsi15.wav
# Converted: spanish96.wav
# Converted: spanish33.wav
# Converted: tajiki2.mp3
# Converted: mandarin42.wav
# Converted: spanish33.mp3
# Converted: portuguese41.mp3
# Converted: marathi2.mp3
# Converted: macedonian7.wav
# Converted: serbian14.mp3
# Converted: english90.mp3
# Converted: english476.wav
# Converted: naxi1.wav
# Converted: russian43.mp3
# Converted: english377.wav
# Converted: arabic48.mp3
# Converted: english183.mp3
# Converted: spanish75.mp3
# Converted: turkish16.wav
# Converted: arabic2.wav
# Converted: bengali6.mp3
# Converted: slovak5.wav
# Converted: krio2.wav
# Converted: czech9.wav
# Converted: japanese26.mp3
# Converted: taiwanese1.mp3
# Converted: japanese20.mp3
# Converted: spanish111.wav
# Converted: hungarian6.wav
# Converted: somali2.wav
# Converted: russian33.wav
# Converted: danish8.wav
# Converted: malay4.wav
# Converted: mandarin64.wav
# Converted: bosnian8.mp3
# Converted: spanish59.wav
# Converted: czech1.mp3
# Converted: english344.wav
# Converted: arabic49.mp3
# Converted: english90.wav
# Converted: romanian12.mp3
# Converted: french33.mp3
# Converted: russian24.wav
# Converted: english351.mp3
# Converted: spanish119.wav
# Converted: turkish14.mp3
# Converted: japanese15.mp3
# Converted: armenian4.mp3
# Converted: urdu2.mp3
# Converted: english196.mp3
# Converted: english284.wav
# Converted: portuguese13.wav
# Converted: english100.mp3
# Converted: bulgarian13.mp3
# Converted: amharic8.wav
# Converted: korean12.wav
# Converted: english429.wav
# Converted: spanish60.wav
# Converted: farsi21.wav
# Converted: english308.mp3
# Converted: english383.mp3
# Converted: mandarin13.wav
# Converted: bulgarian5.wav
# Converted: english374.mp3
# Converted: japanese6.wav
# Converted: portuguese28.mp3
# Converted: french11.mp3
# Converted: mandarin1.wav
# Converted: polish15.mp3
# Converted: german3.wav
# Converted: english291.mp3
# Converted: hausa3.mp3
# Converted: mandarin12.mp3
# Converted: english373.mp3
# Converted: english336.mp3
# Converted: english431.wav
# Converted: greek8.mp3
# Converted: spanish136.wav
# Converted: mandarin31.wav
# Converted: korean24.wav
# Converted: english501.mp3
# Converted: estonian2.mp3
# Converted: vietnamese20.mp3
# Converted: portuguese30.wav
# Converted: portuguese39.mp3
# Converted: german28.mp3
# Converted: slovenian2.mp3
# Converted: ga3.wav
# Converted: thai6.wav
# Converted: spanish159.mp3
# Converted: english385.mp3
# Converted: english327.mp3
# Converted: french9.mp3
# Converted: lithuanian4.mp3
# Converted: kabyle1.mp3
# Converted: english131.mp3
# Converted: mandarin3.wav
# Converted: faroese1.mp3
# Converted: english515.mp3
# Converted: english64.wav
# Converted: italian25.mp3
# Converted: japanese23.mp3
# Converted: mandarin65.wav
# Converted: dutch34.wav
# Converted: portuguese3.mp3
# Converted: english242.mp3
# Converted: mandarin9.mp3
# Converted: spanish53.wav
# Converted: serbian2.mp3
# Converted: korean28.wav
# Converted: vietnamese17.wav
# Converted: portuguese6.mp3
# Converted: russian44.mp3
# Converted: english329.mp3
# Converted: dutch29.wav
# Converted: serbian4.wav
# Converted: french17.wav
# Converted: hausa6.mp3
# Converted: croatian7.wav
# Converted: spanish125.wav
# Converted: ewe2.mp3
# Converted: english54.wav
# Converted: arabic25.wav
# Converted: cantonese6.mp3
# Converted: japanese21.wav
# Converted: vlaams3.mp3
# Converted: polish25.wav
# Converted: english35.mp3
# Converted: english564.wav
# Converted: french2.wav
# Converted: romanian18.wav
# Converted: krio3.wav
# Converted: english573.mp3
# Converted: kiswahili9.mp3
# Converted: portuguese42.wav
# Converted: english138.wav
# Converted: pashto10.wav
# Converted: english89.wav
# Converted: lithuanian2.wav
# Converted: english395.wav
# Converted: korean18.mp3
# Converted: ilonggo1.wav
# Converted: english31.wav
# Converted: japanese23.wav
# Converted: hausa8.mp3
# Converted: bulgarian1.wav
# Converted: german7.mp3
# Converted: hausa3.wav
# Converted: turkish23.mp3
# Converted: english215.wav
# Converted: russian17.mp3
# Converted: chamorro1.mp3
# Converted: english378.wav
# Converted: japanese16.wav
# Converted: english505.wav
# Converted: mandarin52.wav
# Converted: english490.mp3
# Converted: kambaata2.wav
# Converted: thai13.wav
# Converted: english218.wav
# Converted: russian8.wav
# Converted: romanian1.wav
# Converted: bulgarian10.mp3
# Converted: arabic12.mp3
# Converted: dutch32.mp3
# Converted: hebrew8.mp3
# Converted: polish6.mp3
# Converted: ngemba1.mp3
# Converted: spanish128.mp3
# Converted: turkish12.wav
# Converted: vietnamese17.mp3
# Converted: punjabi6.wav
# Converted: polish14.mp3
# Converted: italian27.mp3
# Converted: sindhi1.wav
# Converted: korean20.mp3
# Converted: bengali1.mp3
# Converted: english17.mp3
# Converted: portuguese10.mp3
# Converted: igbo3.mp3
# Converted: burmese2.mp3
# Converted: turkish13.mp3
# Converted: farsi23.wav
# Converted: punjabi7.wav
# Converted: arabic96.mp3
# Converted: spanish130.mp3
# Converted: english32.wav
# Converted: korean22.mp3
# Converted: english422.wav
# Converted: english51.wav
# Converted: polish30.mp3
# Converted: russian6.mp3
# Converted: arabic35.mp3
# Converted: romanian18.mp3
# Converted: korean4.mp3
# Converted: czech7.wav
# Converted: somali4.wav
# Converted: croatian3.wav
# Converted: english33.wav
# Converted: english281.mp3
# Converted: english81.wav
# Converted: kikuyu4.wav
# Converted: english385.wav
# Converted: bosnian1.wav
# Converted: spanish69.mp3
# Converted: armenian4.wav
# Converted: german17.mp3
# Converted: arabic94.mp3
# Converted: hmong1.mp3
# Converted: dutch26.wav
# Converted: english544.wav
# Converted: english261.mp3
# Converted: english263.mp3
# Converted: english502.mp3
# Converted: macedonian25.mp3
# Converted: japanese14.wav
# Converted: xiang4.mp3
# Converted: english8.wav
# Converted: dutch2.mp3
# Converted: english39.wav
# Converted: english200.wav
# Converted: korean13.wav
# Converted: serbian5.mp3
# Converted: english183.wav
# Converted: english419.wav
# Converted: taiwanese8.mp3
# Converted: kikuyu2.wav
# Converted: english359.mp3
# Converted: hebrew5.mp3
# Converted: spanish116.mp3
# Converted: english282.wav
# Converted: arabic95.mp3
# Converted: english461.mp3
# Converted: spanish124.mp3
# Converted: swedish17.wav
# Converted: english566.wav
# Converted: swedish8.wav
# Converted: polish3.wav
# Converted: english263.wav
# Converted: russian30.mp3
# Converted: english185.wav
# Converted: english288.mp3
# Converted: english368.wav
# Converted: kazakh2.wav
# Converted: english179.mp3
# Converted: english119.wav
# Converted: english30.mp3
# Converted: spanish154.mp3
# Converted: mandarin24.mp3
# Converted: bosnian5.wav
# Converted: indonesian2.wav
# Converted: english409.wav
# Converted: korean14.mp3
# Converted: turkish10.wav
# Converted: english493.wav
# Converted: bengali11.mp3
# Converted: arabic23.mp3
# Converted: thai8.mp3
# Converted: english122.wav
# Converted: dinka1.mp3
# Converted: english235.mp3
# Converted: english465.wav
# Converted: english418.mp3
# Converted: bulgarian11.mp3
# Converted: english453.mp3
# Converted: russian35.wav
# Converted: bulgarian17.mp3
# Converted: japanese1.wav
# Converted: russian1.mp3
# Converted: vietnamese20.wav
# Converted: english103.wav
# Converted: taiwanese4.wav
# Converted: italian5.wav
# Converted: hindi2.mp3
# Converted: khmer3.wav
# Converted: kurdish9.mp3
# Converted: czech4.mp3
# Converted: turkish37.mp3
# Converted: english541.mp3
# Converted: english67.mp3
# Converted: spanish57.wav
# Converted: yupik1.wav
# Converted: cantonese22.wav
# Converted: hungarian1.wav
# Converted: bambara1.mp3
# Converted: ebira1.wav
# Converted: albanian1.wav
# Converted: hebrew9.mp3
# Converted: english512.mp3
# Converted: kiswahili4.mp3
# Converted: bengali10.mp3
# Converted: greek11.mp3
# Converted: bulgarian6.mp3
# Converted: farsi1.wav
# Converted: polish11.mp3
# Converted: english320.mp3
# Converted: korean42.mp3
# Converted: greek7.mp3
# Converted: urdu13.mp3
# Converted: english92.wav
# Converted: hindi11.wav
# Converted: punjabi2.mp3
# Converted: english134.mp3
# Converted: russian6.wav
# Converted: english516.mp3
# Converted: english332.mp3
# Converted: tajiki2.wav
# Converted: spanish31.wav
# Converted: italian15.mp3
# Converted: arabic16.mp3
# Converted: romanian7.wav
# Converted: english365.wav
# Converted: fijian2.wav
# Converted: turkish29.mp3
# Converted: dutch3.wav
# Converted: english370.wav
# Converted: english245.mp3
# Converted: english554.mp3
# Converted: english335.mp3
# Converted: japanese12.wav
# Converted: igbo1.mp3
# Converted: dutch35.wav
# Converted: italian30.wav
# Converted: english458.mp3
# Converted: georgian3.wav
# Converted: malay1.wav
# Converted: korean6.mp3
# Converted: french15.mp3
# Converted: french20.mp3
# Converted: english7.mp3
# Converted: arabic88.wav
# Converted: spanish115.mp3
# Converted: armenian7.mp3
# Converted: amharic20.mp3
# Converted: english98.mp3
# Converted: cantonese23.mp3
# Converted: bulgarian15.mp3
# Converted: english84.mp3
# Converted: hindi11.mp3
# Converted: german19.wav
# Converted: spanish108.mp3
# Converted: english280.mp3
# Converted: english250.mp3
# Converted: czech3.wav
# Converted: bafang2.wav
# Converted: polish20.wav
# Converted: mandarin40.mp3
# Converted: vlaams1.mp3
# Converted: tagalog10.wav
# Converted: hakka1.mp3
# Converted: english289.wav
# Converted: quechua2.wav
# Converted: german8.wav
# Converted: portuguese15.mp3
# Converted: english172.mp3
# Converted: bengali5.mp3
# Converted: sylheti1.wav
# Converted: mende3.mp3
# Converted: italian28.wav
# Converted: italian22.wav
# Converted: italian1.wav
# Converted: english249.wav
# Converted: ukrainian1.mp3
# Converted: french47.wav
# Converted: serbian3.wav
# Converted: dutch1.mp3
# Converted: english311.wav
# Converted: spanish9.mp3
# Converted: spanish104.mp3
# Converted: turkish5.mp3
# Converted: amharic7.wav
# Converted: spanish96.mp3
# Converted: macedonian1.wav
# Converted: english509.wav
# Converted: amharic19.wav
# Converted: arabic42.mp3
# Converted: english255.mp3
# Converted: english511.mp3
# Converted: dari5.wav
# Converted: spanish4.mp3
# Converted: swedish12.mp3
# Converted: mandarin51.wav
# Converted: xasonga1.mp3
# Converted: english510.mp3
# Converted: synthesized3.mp3
# Converted: thai5.wav
# Converted: naxi1.mp3
# Converted: tagalog7.mp3
# Converted: bulgarian7.wav
# Converted: english65.wav
# Converted: nepali6.wav
# Converted: russian34.mp3
# Converted: arabic16.wav
# Converted: dutch38.mp3
# Converted: portuguese34.wav
# Converted: english374.wav
# Converted: french52.wav
# Converted: czech6.wav
# Converted: arabic75.wav
# Converted: dutch29.mp3
# Converted: latvian2.mp3
# Converted: marathi1.mp3
# Converted: vietnamese6.mp3
# Converted: english132.wav
# Converted: japanese24.wav
# Converted: english124.mp3
# Converted: arabic57.wav
# Converted: english104.wav
# Converted: german22.wav
# Converted: english16.wav
# Converted: english579.wav
# Converted: english166.mp3
# Converted: macedonian18.wav
# Converted: english66.wav
# Converted: wolof3.wav
# Converted: english414.wav
# Converted: arabic31.mp3
# Converted: english105.mp3
# Converted: bulgarian18.wav
# Converted: tagalog17.wav
# Converted: english134.wav
# Converted: serbian15.mp3
# Converted: english250.wav
# Converted: dutch9.mp3
# Converted: arabic10.mp3
# Converted: synthesized4.mp3
# Converted: arabic62.mp3
# Converted: fataluku1.mp3
# Converted: english110.mp3
# Converted: danish1.wav
# Converted: italian6.mp3
# Converted: spanish159.wav
# Converted: portuguese5.mp3
# Converted: hindi2.wav
# Converted: arabic99.wav
# Converted: cantonese5.mp3
# Converted: german32.mp3
# Converted: vietnamese4.wav
# Converted: english544.mp3
# Converted: cantonese15.wav
# Converted: polish29.wav
# Converted: malay1.mp3
# Converted: english458.wav
# Converted: dari3.mp3
# Converted: arabic96.wav
# Converted: turkish35.mp3
# Converted: georgian5.wav
# Converted: korean1.mp3
# Converted: english198.wav
# Converted: amharic18.mp3
# Converted: english516.wav
# Converted: turkish8.wav
# Converted: finnish1.wav
# Converted: italian24.wav
# Converted: tagalog2.mp3
# Converted: english548.wav
# Converted: telugu2.wav
# Converted: kurdish10.mp3
# Converted: english70.wav
# Converted: fang1.mp3
# Converted: rotuman1.wav
# Converted: polish12.mp3
# Converted: french56.wav
# Converted: english158.wav
# Converted: spanish127.wav
# Converted: dutch24.mp3
# Converted: swedish11.mp3
# Converted: french52.mp3
# Converted: newari1.wav
# Converted: russian22.wav
# Converted: tagalog18.mp3
# Converted: arabic97.wav
# Converted: english535.wav
# Converted: shona2.wav
# Converted: spanish40.mp3
# Converted: english294.wav
# Converted: arabic46.wav
# Converted: portuguese43.wav
# Converted: punjabi4.mp3
# Converted: miskito6.wav
# Converted: spanish155.mp3
# Converted: spanish87.mp3
# Converted: japanese2.wav
# Converted: english79.wav
# Converted: english114.mp3
# Converted: russian2.wav
# Converted: mandarin30.wav
# Converted: english382.wav
# Converted: arabic59.mp3
# Converted: english354.mp3
# Converted: mauritian1.mp3
# Converted: spanish134.wav
# Converted: russian27.mp3
# Converted: serbian8.wav
# Converted: english436.mp3
# Converted: english268.wav
# Converted: urdu8.wav
# Converted: english129.wav
# Converted: arabic74.wav
# Converted: thai4.wav
# Converted: italian10.wav
# Converted: pashto6.mp3
# Converted: amharic11.mp3
# Converted: english81.mp3
# Converted: oriya2.mp3
# Converted: english452.wav
# Converted: english14.wav
# Converted: fanti3.mp3
# Converted: english100.wav
# Converted: sarua1.wav
# Converted: turkish1.wav
# Converted: romanian7.mp3
# Converted: finnish4.mp3
# Converted: english133.wav
# Converted: english523.wav
# Converted: dutch30.mp3
# Converted: norwegian2.mp3
# Converted: english55.wav
# Converted: macedonian20.wav
# Converted: spanish67.mp3
# Converted: italian16.wav
# Converted: russian31.mp3
# Converted: edo1.mp3
# Converted: czech3.mp3
# Converted: turkish2.wav
# Converted: mandarin55.wav
# Converted: mandarin14.mp3
# Converted: hindi10.mp3
# Converted: tagalog6.mp3
# Converted: german5.wav
# Converted: english143.mp3
# Converted: spanish112.wav
# Converted: portuguese20.mp3
# Converted: french38.mp3
# Converted: english442.wav
# Converted: english40.wav
# Converted: english237.mp3
# Converted: slovenian1.wav
# Converted: hebrew3.mp3
# Converted: nandi1.mp3
# Converted: english205.wav
# Converted: english58.mp3
# Converted: hausa9.mp3
# Converted: english561.wav
# Converted: serbian14.wav
# Converted: korean43.wav
# Converted: english504.wav
# Converted: farsi11.wav
# Converted: khmer1.wav
# Converted: hadiyya2.wav
# Converted: portuguese29.wav
# Converted: dutch12.wav
# Converted: polish4.mp3
# Converted: spanish63.wav
# Converted: azerbaijani3.mp3
# Converted: russian10.mp3
# Converted: czech1.wav
# Converted: japanese27.wav
# Converted: miskito8.mp3
# Converted: spanish126.wav
# Converted: latvian3.mp3
# Converted: spanish35.mp3
# Converted: nepali13.mp3
# Converted: spanish42.wav
# Converted: english453.wav
# Converted: satawalese1.wav
# Converted: spanish152.mp3
# Converted: english211.mp3
# Converted: danish1.mp3
# Converted: spanish13.mp3
# Converted: english475.mp3
# Converted: english45.wav
# Converted: english321.mp3
# Converted: spanish29.wav
# Converted: korean30.wav
# Converted: mende1.wav
# Converted: english561.mp3
# Converted: farsi6.mp3
# Converted: english421.wav
# Converted: english27.mp3
# Converted: bulgarian12.mp3
# Converted: arabic98.wav
# Converted: ukrainian7.mp3
# Converted: czech2.mp3
# Converted: portuguese16.mp3
# Converted: italian17.wav
# Converted: turkish17.wav
# Converted: english74.mp3
# Converted: mandarin40.wav
# Converted: english175.wav
# Converted: malay5.wav
# Converted: russian48.mp3
# Converted: mandarin25.wav
# Converted: spanish45.wav
# Converted: ife1.wav
# Converted: vlaams3.wav
# Converted: spanish105.mp3
# Converted: french32.wav
# Converted: mandarin10.mp3
# Converted: arabic45.wav
# Converted: english256.wav
# Converted: english491.wav
# Converted: english69.wav
# Converted: mongolian5.mp3
# Converted: english178.mp3
# Converted: arabic51.mp3
# Converted: miskito8.wav
# Converted: lao1.wav
# Converted: english381.wav
# Converted: english560.mp3
# Converted: mandarin34.wav
# Converted: spanish146.wav
# Converted: polish6.wav
# Converted: ga3.mp3
# Converted: russian28.mp3
# Converted: english463.mp3
# Converted: russian5.wav
# Converted: spanish3.mp3
# Converted: english186.mp3
# Converted: vietnamese8.wav
# Converted: mandarin59.mp3
# Converted: french31.wav
# Converted: spanish149.wav
# Converted: mandarin23.wav
# Converted: french5.wav
# Converted: english41.mp3
# Converted: czech9.mp3
# Converted: english359.wav
# Converted: english5.wav
# Converted: english450.mp3
# Converted: english292.mp3
# Converted: hausa5.wav
# Converted: russian18.mp3
# Converted: mandarin32.wav
# Converted: turkish27.wav
# Converted: english96.mp3
# Converted: yoruba3.wav
# Converted: english351.wav
# Converted: english314.mp3
# Converted: french36.wav
# Converted: french4.wav
# Converted: spanish157.mp3
# Converted: english470.wav
# Converted: tagalog14.wav
# Converted: serbian11.mp3
# Converted: quechua1.mp3
# Converted: bulgarian9.wav
# Converted: albanian8.mp3
# Converted: tigrigna8.mp3
# Converted: polish16.wav
# Converted: burmese1.wav
# Converted: french15.wav
# Converted: english504.mp3
# Converted: arabic36.mp3
# Converted: german8.mp3
# Converted: english301.mp3
# Converted: urdu16.mp3
# Converted: jola1.mp3
# Converted: albanian7.mp3
# Converted: dutch30.wav
# Converted: english44.mp3
# Converted: ukrainian11.wav
# Converted: french26.mp3
# Converted: somali3.mp3
# Converted: ewe1.mp3
# Converted: macedonian21.mp3
# Converted: korean7.mp3
# Converted: english177.mp3
# Converted: bengali7.wav
# Converted: mende3.wav
# Converted: arabic27.wav
# Converted: indonesian4.mp3
# Converted: english425.wav
# Converted: vietnamese22.mp3
# Converted: mandarin45.mp3
# Converted: english225.mp3
# Converted: korean8.wav
# Converted: german1.wav
# Converted: kurdish7.wav
# Converted: portuguese47.mp3
# Converted: russian5.mp3
# Converted: macedonian6.wav
# Converted: arabic28.mp3
# Converted: italian8.mp3
# Converted: english390.mp3
# Converted: english552.wav
# Converted: spanish63.mp3
# Converted: russian32.wav
# Converted: english223.mp3
# Converted: swedish19.wav
# Converted: japanese8.mp3
# Converted: english387.wav
# Converted: portuguese32.wav
# Converted: serbian8.mp3
# Converted: frisian1.mp3
# Converted: arabic18.mp3
# Converted: english491.mp3
# Converted: shan1.mp3
# Converted: english204.mp3
# Converted: polish34.wav
# Converted: indonesian8.mp3
# Converted: malayalam1.wav
# Converted: russian12.mp3
# Converted: agni1.mp3
# Converted: english171.wav
# Converted: swedish9.wav
# Converted: georgian1.mp3
# Converted: polish10.mp3
# Converted: portuguese17.wav
# Converted: bengali8.wav
# Converted: mandarin30.mp3
# Converted: oromo1.wav
# Converted: greek2.mp3
# Converted: agni1.wav
# Converted: tatar1.wav
# Converted: english190.wav
# Converted: indonesian1.mp3
# Converted: kazakh3.wav
# Converted: korean8.mp3
# Converted: english525.mp3
# Converted: mandarin52.mp3
# Converted: bengali14.mp3
# Converted: russian9.mp3
# Converted: english316.mp3
# Converted: somali6.wav
# Converted: english440.wav
# Converted: arabic100.mp3
# Converted: english477.wav
# Converted: bengali4.wav
# Converted: english367.mp3
# Converted: vietnamese1.mp3
# Converted: english1.wav
# Converted: croatian2.mp3
# Converted: russian36.mp3
# Converted: taiwanese4.mp3
# Converted: french46.mp3
# Converted: bafang2.mp3
# Converted: spanish124.wav
# Converted: english251.mp3
# Converted: dutch41.mp3
# Converted: kikuyu1.mp3
# Converted: romanian10.wav
# Converted: nama1.mp3
# Converted: english71.mp3
# Converted: french63.wav
# Converted: arabic79.mp3
# Converted: arabic58.wav
# Converted: english61.mp3
# Converted: uyghur2.wav
# Converted: tagalog15.wav
# Converted: english578.mp3
# Converted: italian30.mp3
# Converted: serbian18.wav
# Converted: english483.wav
# Converted: arabic35.wav
# Converted: mandinka1.wav
# Converted: korean41.wav
# Converted: english144.wav
# Converted: arabic41.wav
# Converted: arabic93.mp3
# Converted: russian37.wav
# Converted: english499.wav
# Converted: swedish2.mp3
# Converted: bamun1.mp3
# Converted: macedonian8.mp3
# Converted: english481.wav
# Converted: korean49.wav
# Converted: arabic7.wav
# Converted: mende2.mp3
# Converted: cantonese17.wav
# Converted: english114.wav
# Converted: polish9.wav
# Converted: synthesized3.wav
# Converted: english571.wav
# Converted: english146.wav
# Converted: english525.wav
# Converted: english483.mp3
# Converted: serbian6.mp3
# Converted: english40.mp3
# Converted: german24.wav
# Converted: macedonian19.wav
# Converted: fijian2.mp3
# Converted: german15.mp3
# Converted: punjabi9.wav
# Converted: english276.mp3
# Converted: english253.wav
# Converted: french40.wav
# Converted: mende1.mp3
# Converted: english295.wav
# Converted: carolinian1.mp3
# Converted: english138.mp3
# Converted: french38.wav
# Converted: finnish1.mp3
# Converted: albanian5.mp3
# Converted: korean47.wav
# Converted: amharic14.mp3
# Converted: arabic58.mp3
# Converted: italian16.mp3
# Converted: english297.wav
# Converted: french39.mp3
# Converted: kurdish8.wav
# Converted: bosnian6.wav
# Converted: russian32.mp3
# Converted: english529.mp3
# Converted: english410.mp3
# Converted: english412.mp3
# Converted: taiwanese2.mp3
# Converted: english326.wav
# Converted: italian7.mp3
# Converted: xiang1.mp3
# Converted: english432.mp3
# Converted: english180.wav
# Converted: german13.mp3
# Converted: spanish49.wav
# Converted: english167.mp3
# Converted: english217.mp3
# Converted: english237.wav
# Converted: spanish77.mp3
# Converted: english308.wav
# Converted: english217.wav
# Converted: english41.wav
# Converted: latvian1.wav
# Converted: english482.mp3
# Converted: french61.wav
# Converted: nepali4.mp3
# Converted: wolof5.mp3
# Converted: wolof6.mp3
# Converted: vietnamese13.mp3
# Converted: georgian1.wav
# Converted: english547.mp3
# Converted: arabic8.mp3
# Converted: mongolian5.wav
# Converted: english94.wav
# Converted: dutch28.wav
# Converted: english467.wav
# Converted: tagalog9.mp3
# Converted: pashto7.mp3
# Converted: serbian10.mp3
# Converted: bulgarian5.mp3
# Converted: french4.mp3
# Converted: portuguese10.wav
# Converted: english270.wav
# ...
# Converted: bulgarian15.wav
# Converted: english489.wav
# Converted: turkish26.mp3
# Converted: estonian1.mp3
# Converted: malay2.mp3
# Converted: english360.mp3
# Converted: turkish8.mp3
# Converted: russian11.wav
# Converted: spanish25.wav
# Converted: english219.wav
# Converted: english455.wav
# Converted: spanish134.mp3
# Converted: hainanese1.mp3
# Converted: spanish117.wav
# Converted: english498.mp3
# Converted: spanish129.wav
# Converted: catalan3.mp3
# Converted: croatian6.mp3
# Converted: lithuanian4.wav
# Converted: cebuano1.wav
# Converted: cantonese20.mp3
# Converted: english162.mp3
# Converted: portuguese44.mp3
# Converted: english562.mp3
# Converted: english290.mp3
# Converted: english275.wav
# Converted: kikongo1.wav
# Converted: english172.wav
# Converted: turkish6.wav
# Converted: greek3.wav
# Converted: english147.mp3
# Converted: maltese2.wav
# Converted: yiddish2.wav
# Converted: arabic50.wav
# Converted: russian3.mp3
# Converted: kanuri1.mp3
# Converted: vietnamese18.wav
# Converted: kiswahili8.mp3
# Converted: polish26.wav
# Converted: arabic92.mp3
# Converted: english575.mp3
# Converted: arabic94.wav
# Converted: arabic83.wav
# Converted: arabic13.wav
# Converted: cantonese21.mp3
# Converted: spanish114.mp3
# Converted: macedonian17.wav
# Converted: spanish50.mp3
# Converted: amharic4.wav
# Converted: english58.wav
# Converted: polish22.mp3
# Converted: english180.mp3
# Converted: portuguese1.mp3
# Converted: polish2.mp3
# Converted: french35.wav
# Converted: spanish61.mp3
# Converted: nepali11.wav
# Converted: english361.mp3
# Converted: portuguese5.wav
# Converted: khmer7.wav
# Converted: mandarin1.mp3
# Converted: english401.wav
# Converted: spanish118.wav
# Converted: spanish65.wav
# Converted: romanian15.wav
# Converted: hindi13.wav
# Converted: english370.mp3
# Converted: english550.wav
# Converted: bengali17.mp3
# Converted: kiswahili3.mp3
# Converted: spanish120.mp3
# Converted: pashto9.wav
# Converted: dari2.mp3
# Converted: bulgarian1.mp3
# Converted: arabic87.mp3
# Converted: macedonian21.wav
# Converted: english197.mp3
# Converted: arabic24.wav
# Converted: nepali10.mp3
# Converted: english286.wav
# Converted: portuguese18.mp3
# Converted: arabic8.wav
# Converted: dutch20.mp3
# Converted: mandarin54.mp3
# Converted: french34.mp3
# Converted: catalan4.mp3
# Converted: japanese26.wav
# Converted: english366.mp3
# Converted: english579.mp3
# Converted: tamil6.wav
# Converted: amharic10.mp3
# Converted: mandarin20.wav
# Converted: portuguese25.mp3
# Converted: hebrew2.mp3
# Converted: english146.mp3
# Converted: spanish56.mp3
# Converted: mongolian7.mp3
# Converted: arabic86.wav
# Converted: nama1.wav
# Converted: estonian4.mp3
# Converted: english202.wav
# Converted: igbo2.wav
# Converted: english508.wav
# Converted: english87.wav
# Converted: russian21.mp3
# Converted: mandarin61.mp3
# Converted: tagalog8.wav
# Converted: russian41.wav
# Converted: english59.wav
# Converted: albanian6.wav
# Converted: english427.mp3
# Converted: croatian8.mp3
# Converted: belarusan2.mp3
# Converted: tamil5.wav
# Converted: yoruba5.wav
# Converted: english537.wav
# Converted: italian33.mp3
# Converted: english426.mp3
# Converted: english428.wav
# Converted: spanish53.mp3
# Converted: arabic81.wav
# Converted: tagalog14.mp3
# Converted: english123.mp3
# Converted: arabic64.mp3
# Converted: vietnamese12.mp3
# Converted: russian44.wav
# Converted: english317.mp3
# Converted: korean31.wav
# Converted: lithuanian5.mp3
# Converted: japanese9.wav
# Converted: teochew1.wav
# Converted: arabic2.mp3
# Converted: spanish90.wav
# Converted: kirghiz1.mp3
# Converted: kurdish5.mp3
# Converted: amazigh2.wav
# Converted: basque2.wav
# Converted: korean31.mp3
# Converted: chaldean2.mp3
# Converted: french50.wav
# Converted: english299.mp3
# Converted: macedonian1.mp3
# Converted: spanish128.wav
# Converted: malayalam3.mp3
# Converted: uzbek3.wav
# Converted: swedish5.wav
# Converted: dutch34.mp3
# Converted: portuguese35.wav
# Converted: arabic82.wav
# Converted: english315.wav
# Converted: yiddish4.mp3
# Converted: arabic33.mp3
# Converted: yoruba2.mp3
# Converted: spanish119.mp3
# Converted: english174.wav
# Converted: korean42.wav
# Converted: russian35.mp3
# Converted: arabic17.wav
# Converted: german35.mp3
# Converted: english287.mp3
# Converted: english319.wav
# Converted: swedish15.wav
# Converted: pashto7.wav
# Converted: romanian1.mp3
# Converted: english80.wav
# Converted: german24.mp3
# Converted: wolof4.mp3
# Converted: english207.mp3
# Converted: belarusan3.mp3
# Converted: thai13.mp3
# Converted: english386.mp3
# Converted: english35.wav
# Converted: english72.mp3
# Converted: english333.wav
# Converted: swedish7.mp3
# Converted: turkish26.wav
# Converted: ga4.wav
# Converted: vlaams1.wav
# Converted: english479.mp3
# Converted: rotuman1.mp3
# Converted: french55.mp3
# Converted: german21.wav
# Converted: german30.wav
# Converted: french51.wav
# Converted: ukrainian5.wav
# Converted: punjabi5.mp3
# Converted: english216.wav
# Converted: english125.mp3
# Converted: spanish116.wav
# Converted: dutch4.mp3
# Converted: farsi13.wav
# Converted: french25.wav
# Converted: english542.wav
# Converted: chittagonian1.mp3
# Converted: latvian1.mp3
# Converted: spanish139.mp3
# Converted: french22.mp3
# Converted: romanian9.mp3
# Converted: farsi12.mp3
# Converted: english61.wav
# Converted: italian1.mp3
# Converted: dutch44.wav
# Converted: farsi22.wav
# Converted: khmer6.mp3
# Converted: greek3.mp3
# Converted: spanish67.wav
# Converted: dutch17.wav
# Converted: dutch23.mp3
# Converted: english150.wav
# Converted: english424.mp3
# Converted: english279.mp3
# Converted: albanian2.wav
# Converted: german16.mp3
# Converted: macedonian16.wav
# Converted: slovak1.mp3
# Converted: portuguese22.wav
# Converted: latvian3.wav
# Converted: wolof4.wav
# Converted: mandarin34.mp3
# Converted: english290.wav
# Converted: vietnamese1.wav
# Converted: portuguese28.wav
# Converted: gusii2.mp3
# Converted: polish20.mp3
# Converted: burmese1.mp3
# Converted: german15.wav
# Converted: spanish93.wav
# Converted: tibetan1.mp3
# Converted: english536.mp3
# Converted: hungarian9.mp3
# Converted: mandarin36.mp3
# Converted: english343.wav
# Converted: english6.wav
# Converted: fang1.wav
# Converted: filipino2.mp3
# Converted: english547.wav
# Converted: spanish92.mp3
# Converted: baga1.mp3
# Converted: hindi18.wav
# Converted: farsi5.mp3
# Converted: khmer6.wav
# Converted: spanish30.wav
# Converted: bosnian2.mp3
# Converted: bengali6.wav
# Converted: susu1.mp3
# Converted: english137.mp3
# Converted: german14.mp3
# Converted: dutch47.wav
# Converted: vietnamese11.mp3
# Converted: czech6.mp3
# Converted: bambara1.wav
# Converted: fanti2.mp3
# Converted: mandarin8.wav
# Converted: arabic14.mp3
# Converted: japanese12.mp3
# Converted: english473.wav
# Converted: kikongo2.mp3
# Converted: spanish97.wav
# Converted: farsi10.mp3
# Converted: korean35.mp3
# Converted: spanish21.wav
# Converted: spanish84.mp3
# Converted: mandarin51.mp3
# Converted: spanish70.mp3
# Converted: macedonian18.mp3
# Converted: english60.wav
# Converted: english192.wav
# Converted: english457.wav
# Converted: english434.wav
# Converted: konkani1.mp3
# Converted: spanish80.wav
# Converted: mandarin64.mp3
# Converted: miskito9.mp3
# Converted: turkish25.wav
# Converted: xasonga1.wav
# Converted: english400.wav
# Converted: pulaar3.mp3
# Converted: english252.mp3
# Converted: russian9.wav
# Converted: english452.mp3
# Converted: kabyle1.wav
# Converted: turkish19.wav
# Converted: korean48.mp3
# Converted: temne1.wav
# Converted: miskito5.wav
# Converted: kazakh2.mp3
# Converted: english274.mp3
# Converted: mandarin18.mp3
# Converted: english209.wav
# Converted: spanish62.mp3
# Converted: bengali5.wav
# Converted: english451.wav
# Converted: russian23.wav
# Converted: english118.wav
# Converted: swedish10.mp3
# Converted: hainanese1.wav
# Converted: italian6.wav
# Converted: german33.mp3
# Converted: english323.mp3
# Converted: hungarian5.mp3
# Converted: cantonese14.mp3
# Converted: hebrew9.wav
# Converted: punjabi2.wav
# Converted: spanish132.mp3
# Converted: mandarin59.wav
# Converted: gedeo1.mp3
# Converted: hungarian8.wav
# Converted: polish15.wav
# Converted: english413.wav
# Converted: taiwanese3.wav
# Converted: english404.wav
# Converted: english402.mp3
# Converted: bengali16.wav
# Converted: english186.wav
# Converted: khmer3.mp3
# Converted: hebrew5.wav
# Converted: dutch14.wav
# Converted: hindi4.wav
# Converted: belarusan1.mp3
# Converted: english156.mp3
# Converted: french30.mp3
# Converted: english187.mp3
# Converted: greek9.mp3
# Converted: serbian9.mp3
# Converted: spanish123.wav
# Converted: farsi5.wav
# Converted: krio3.mp3
# Converted: english520.wav
# Converted: kikuyu2.mp3
# Converted: french1.wav
# Converted: turkish16.mp3
# Converted: french26.wav
# Converted: english322.wav
# Converted: english116.wav
# Converted: tswana2.wav
# Converted: dutch25.mp3
# Converted: spanish11.wav
# Converted: turkish15.mp3
# Converted: korean37.wav
# Converted: portuguese38.wav
# Converted: arabic76.wav
# Converted: english325.mp3
# Converted: english474.mp3
# Converted: korean34.mp3
# Converted: english163.mp3
# Converted: miskito2.wav
# Converted: english443.mp3
# Converted: italian26.mp3
# Converted: macedonian5.mp3
# Converted: english361.wav
# Converted: russian7.wav
# Converted: russian21.wav
# Converted: bengali12.mp3
# Converted: bulgarian16.wav
# Converted: english512.wav
# Converted: spanish102.wav
# Converted: nepali4.wav
# Converted: english393.wav
# Converted: fanti3.wav
# Converted: urdu16.wav
# Converted: english201.wav
# Converted: russian45.wav
# Converted: macedonian10.wav
# Converted: fijian3.wav
# Converted: bai1.mp3
# Converted: english408.mp3
# Converted: english266.mp3
# Converted: portuguese8.wav
# Converted: finnish7.wav
# Converted: english72.wav
# Converted: english430.mp3
# Converted: english325.wav
# Converted: english163.wav
# Converted: somali4.mp3
# Converted: mandarin33.mp3
# Converted: farsi17.mp3
# Converted: ngemba2.wav
# Converted: french60.wav
# Converted: korean15.mp3
# Converted: miskito3.wav
# Converted: spanish60.mp3
# Converted: spanish156.wav
# Converted: english403.wav
# Converted: macedonian15.wav
# Converted: ukrainian8.wav
# Converted: gusii2.wav
# Converted: punjabi7.mp3
# Converted: korean2.mp3
# Converted: german6.mp3
# Converted: macedonian17.mp3
# Converted: taiwanese1.wav
# Converted: dari3.wav
# Converted: lamotrekese1.mp3
# Converted: english322.mp3
# Converted: spanish56.wav
# Converted: english195.mp3
# Converted: english487.wav
# Converted: thai2.mp3
# Converted: kurdish9.wav
# Converted: bulgarian6.wav
# Converted: thai12.wav
# Converted: mandarin43.mp3
# Converted: japanese24.mp3
# Converted: gujarati2.wav
# Converted: english315.mp3
# Converted: basque2.mp3
# Converted: english246.wav
# Converted: english502.wav
# Converted: spanish130.wav
# Converted: xiang3.mp3
# Converted: english190.mp3
# Converted: spanish108.wav
# Converted: french50.mp3
# Converted: dutch35.mp3
# Converted: english506.mp3
# Converted: arabic102.wav
# Converted: english568.wav
# Converted: english73.wav
# Converted: english142.mp3
# Converted: english391.wav
# Converted: kiswahili9.wav
# Converted: english442.mp3
# Converted: italian26.wav
# Converted: vlaams2.mp3
# Converted: turkish23.wav
# Converted: tagalog17.mp3
# Converted: russian12.wav
# Converted: cantonese7.mp3
# Converted: spanish37.wav
# Converted: russian18.wav
# Converted: english70.mp3
# Converted: cantonese19.mp3
# Converted: fataluku1.wav
# Converted: miskito5.mp3
# Converted: albanian3.wav
# Converted: arabic22.wav
# Converted: vietnamese9.wav
# Converted: spanish12.mp3
# Converted: dutch43.mp3
# Converted: german18.wav
# Converted: english342.mp3
# Converted: serbian1.wav
# Converted: telugu2.mp3
# Converted: french31.mp3
# Converted: taiwanese5.wav
# Converted: estonian3.mp3
# Converted: russian28.wav
# Converted: german16.wav
# Converted: mandarin15.wav
# Converted: belarusan2.wav
# Converted: serbian17.mp3
# Converted: german21.mp3
# Converted: pashto8.wav
# Converted: arabic1.mp3
# Converted: portuguese14.wav
# Converted: english528.wav
# Converted: english50.mp3
# Converted: english567.mp3
# Converted: spanish145.wav
# Converted: english64.mp3
# Converted: nepali9.wav
# Converted: vietnamese16.wav
# Converted: arabic93.wav
# Converted: english558.mp3
# Converted: krio1.mp3
# Converted: korean21.wav
# Converted: spanish75.wav
# Converted: farsi21.mp3
# Converted: italian3.wav
# Converted: korean25.mp3
# Converted: macedonian19.mp3
# Converted: english141.mp3
# Converted: quechua1.wav
# Converted: bulgarian4.mp3
# Converted: french44.wav
# Converted: polish23.mp3
# Converted: english153.mp3
# Converted: english518.mp3
# Converted: english218.mp3
# Converted: korean23.wav
# Converted: bengali9.mp3
# Converted: english164.mp3
# Converted: english496.wav
# Converted: english337.mp3
# Converted: papiamentu2.mp3
# Converted: kambaata3.wav
# Converted: english151.mp3
# Converted: english444.wav
# Converted: vietnamese7.mp3
# Converted: spanish40.wav
# Converted: english254.mp3
# Converted: french47.mp3
# Converted: arabic39.mp3
# Converted: polish1.wav
# Converted: english271.mp3
# Converted: turkish22.mp3
# Converted: sindhi1.mp3
# Converted: spanish68.wav
# Converted: english243.mp3
# Converted: english210.wav
# Converted: spanish152.wav
# Converted: arabic52.wav
# Converted: korean23.mp3
# Converted: azerbaijani2.mp3
# Converted: papiamentu1.wav
# Converted: amharic5.wav
# Converted: english457.mp3
# Converted: kambaata1.mp3
# Converted: english372.mp3
# Converted: portuguese40.mp3
# Converted: romanian8.mp3
# Converted: korean38.mp3
# Converted: english333.mp3
# Converted: xiang2.mp3
# Converted: ukrainian8.mp3
# Converted: dutch12.mp3
# Converted: bambara3.wav
# Converted: czech4.wav
# Converted: spanish122.wav
# Converted: english169.wav
# Converted: japanese27.mp3
# Converted: english473.mp3
# Converted: english506.wav
# Converted: czech2.wav
# Converted: kiswahili1.wav
# Converted: dutch26.mp3
# Converted: bambara5.mp3
# Converted: urdu3.wav
# Converted: japanese19.wav
# Converted: arabic67.mp3
# Converted: arabic15.wav
# ✓ Processed: serbian15.wav
# ✓ Processed: arabic9.wav
# ✓ Processed: spanish83.wav
# ✓ Processed: polish30.wav
# ✓ Processed: amharic14.wav
# ✓ Processed: dutch15.wav
# ✓ Processed: english551.wav
# ✓ Processed: miskito1.wav
# ✓ Processed: amharic2.wav
# ✓ Processed: english187.wav
# ✓ Processed: mandarin7.wav
# ✓ Processed: amharic20.wav
# ✓ Processed: amharic10.wav
# ✓ Processed: norwegian4.wav
# ✓ Processed: arabic40.wav
# ✓ Processed: arabic36.wav
# ✓ Processed: spanish103.wav
# ✓ Processed: pulaar3.wav
# ✓ Processed: mandingo1.wav
# ✓ Processed: spanish44.wav
# ✓ Processed: yiddish1.wav
# ✓ Processed: spanish5.wav
# ✓ Processed: english283.wav
# ✓ Processed: russian3.wav
# ✓ Processed: german17.wav
# ✓ Processed: bosnian8.wav
# ✓ Processed: hebrew2.wav
# ✓ Processed: kikuyu3.wav
# ✓ Processed: portuguese25.wav
# ✓ Processed: indonesian8.wav
# ✓ Processed: english236.wav
# ✓ Processed: mandarin11.wav
# ✓ Processed: georgian4.wav
# ✓ Processed: english193.wav
# ✓ Processed: polish32.wav
# ✓ Processed: macedonian25.wav
# ✓ Processed: english232.wav
# ✓ Processed: spanish142.wav
# ✓ Processed: nepali3.wav
# ✓ Processed: spanish133.wav
# ✓ Processed: russian27.wav
# ✓ Processed: malayalam2.wav
# ✓ Processed: italian9.wav
# ✓ Processed: malayalam3.wav
# ✓ Processed: burmese2.wav
# ✓ Processed: kurdish3.wav
# ✓ Processed: english313.wav
# ✓ Processed: english139.wav
# ✓ Processed: portuguese1.wav
# ✓ Processed: spanish71.wav
# ✓ Processed: bambara5.wav
# ✓ Processed: czech5.wav
# ✓ Processed: english511.wav
# ✓ Processed: tamil2.wav
# ✓ Processed: english155.wav
# ✓ Processed: croatian4.wav
# ✓ Processed: tswana1.wav
# ✓ Processed: german26.wav
# ✓ Processed: japanese17.wav
# ✓ Processed: spanish66.wav
# ✓ Processed: gujarati1.wav
# ✓ Processed: english574.wav
# ✓ Processed: turkish22.wav
# ✓ Processed: konkani1.wav
# ✓ Processed: macedonian12.wav
# ✓ Processed: italian27.wav
# ✓ Processed: marathi2.wav
# ✓ Processed: bengali11.wav
# ✓ Processed: carolinian1.wav
# ✓ Processed: dutch21.wav
# ✓ Processed: mandarin9.wav
# ✓ Processed: bambara2.wav
# ✓ Processed: english439.wav
# ✓ Processed: english328.wav
# ✓ Processed: english346.wav
# ✓ Processed: lithuanian6.wav
# ✓ Processed: farsi2.wav
# ✓ Processed: english517.wav
# ✓ Processed: arabic44.wav
# ✓ Processed: english213.wav
# ✓ Processed: romanian6.wav
# ✓ Processed: spanish26.wav
# ✓ Processed: kikongo2.wav
# ✓ Processed: spanish86.wav
# ✓ Processed: farsi19.wav
# ✓ Processed: english364.wav
# ✓ Processed: russian46.wav
# ✓ Processed: portuguese44.wav
# ✓ Processed: english102.wav
# ✓ Processed: russian19.wav
# ✓ Processed: hakka1.wav
# ✓ Processed: english75.wav
# ✓ Processed: polish14.wav
# ✓ Processed: amharic12.wav
# ✓ Processed: mandarin45.wav
# ✓ Processed: dutch1.wav
# ✓ Processed: english4.wav
# ✓ Processed: english20.wav
# ✓ Processed: english448.wav
# ✓ Processed: dutch20.wav
# ✅ Upserted batch 2 (Total vectors: 200)
# 📄 Embeddings saved to: /content/sample_data/audio_samples/embeddings.csv

# %%
# Test similarity search
index = init_pinecone()
test_audio = "/content/sample_data/audio_samples/audio_wav/tamil2.wav"
test_similarity_search(test_audio, index, top_k=3)
# Out:
# 🔍 Similarity Search for: tamil2.wav
# 1. tamil2.wav (Score: 1.0000)
# 2. tamil2.wav (Score: 1.0000)
# 3. tamil2.wav (Score: 1.0000)

# %%
def select_random_subset(embeddings, metadata_list, subset_size=100):
    if len(embeddings) <= subset_size:
        return embeddings, metadata_list

    indices = np.random.choice(len(embeddings), subset_size, replace=False)
    subset_embeddings = [embeddings[i] for i in indices]
    subset_metadata = [metadata_list[i] for i in indices]

    return subset_embeddings, subset_metadata

# %%
def cosine_similarity(a, b):
  # Ensure inputs are numpy arrays and handle potential division by zero
  a = np.asarray(a)
  b = np.asarray(b)
  dot_product = np.dot(a, b)
  norm_a = np.linalg.norm(a)
  norm_b = np.linalg.norm(b)
  if norm_a == 0 or norm_b == 0:
      return 0.0  # Or handle as appropriate, returning 0 for zero vectors
  return dot_product / (norm_a * norm_b)

# %%
def evaluate_embeddings(embeddings, labels):
    n_samples = len(embeddings)
    similarity_scores = []
    y_true = []

    # Calculate pairwise similarity and true labels
    for i in range(n_samples):
        for j in range(i + 1, n_samples):
            # Calculate cosine similarity using the defined function
            score = cosine_similarity(embeddings[i], embeddings[j])
            similarity_scores.append(score)

            # Determine true label (1 if same label, 0 if different)
            true_label = 1 if labels[i] == labels[j] else 0
            y_true.append(true_label)

    y_true = np.array(y_true)
    similarity_scores = np.array(similarity_scores)

    threshold = np.mean(similarity_scores)

    y_pred = (similarity_scores >= threshold).astype(int)

    return y_true, y_pred, similarity_scores

# %%
# Check if embeddings and metadata_list are available
if 'embeddings' in locals() and embeddings and 'metadata_list' in locals() and metadata_list:
    # Pick a random subset for evaluation (for example, 100 samples)
    subset_embeddings, subset_metadata = select_random_subset(
        embeddings, metadata_list, subset_size=100)

    # Derive labels from the metadata_list
    subset_labels = [metadata['file_name'].split('.')[0].split('_')[0] for metadata in subset_metadata]

    # Evaluate the embeddings
    y_true, y_pred, similarity_scores = evaluate_embeddings(subset_embeddings, subset_labels)


    # Calculate evaluation metrics
    accuracy = accuracy_score(y_true, y_pred)
    # Use zero_division=1 to avoid warnings if there are no positive predictions
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='binary', zero_division=1)


    # Calculate EER
    if len(np.unique(y_true)) > 1:
      fpr, tpr, thresholds = roc_curve(y_true, similarity_scores)
      # Find the threshold where (1 - tpr) is closest to fpr
      eer = fpr[np.nanargmin(np.absolute((1 - tpr) - fpr))]
      print(f"Approximate EER: {eer:.4f}")

      # Plot ROC curve
      plt.figure(figsize=(10, 5))
      plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc(fpr, tpr))
      plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
      plt.xlim([0.0, 1.0])
      plt.ylim([0.0, 1.05])
      plt.xlabel('False Positive Rate (FPR)')
      plt.ylabel('True Positive Rate (TPR)')
      plt.title('Receiver Operating Characteristic (ROC) Curve')
      plt.legend(loc="lower right")
      plt.show()
    else:
      print("Cannot calculate EER or plot ROC curve: Not enough unique classes in the subset for evaluation.")


    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

else:
    print("Embeddings or metadata_list not found. Please run the audio processing step first.")
# Out:
# Cannot calculate EER or plot ROC curve: Not enough unique classes in the subset for evaluation.
# Accuracy: 0.5493
# Precision: 0.0000, Recall: 1.0000, F1: 0.0000
